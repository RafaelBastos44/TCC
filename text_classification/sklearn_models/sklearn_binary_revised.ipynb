# %% [markdown]
# # Importing libraries

# %%
# Basic libraries
import pandas as pd
import time

# Classification models
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import MultinomialNB

# Vectorizers
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# Utilities and metrics
from itertools import product
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score, precision_score, recall_score

# Preprocessing
import nltk
import re

# Download nltk resources
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\rafae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Setting seeds

# %%
s1 = 418380670049
s2 = 5522499
s3 = 29114468376207731

seeds = [s1, s2, s3]

# %% [markdown]
# # Importing datasets

# %%
path = r'../data/binary/hate/'

train = pd.read_parquet(path + 'train-00000-of-00001.parquet')
test = pd.read_parquet(path + 'test-00000-of-00001.parquet')
val = pd.read_parquet(path + 'validation-00000-of-00001.parquet')

# %% [markdown]
# # Dataset preprocessing

# %%
stop_words = set(nltk.corpus.stopwords.words('english'))
lemmatizer = nltk.stem.WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()

    text = re.sub(r'[^\w\s]', '', text)
    
    words = text.split()
    words = [word for word in words if word not in stop_words]
    words = [lemmatizer.lemmatize(word) for word in words]

    return ' '.join(words)

train['text'] = train['text'].apply(preprocess_text)

# %% [markdown]
# # Text vectorization

# %%
tfidf = TfidfVectorizer()
count = CountVectorizer()

vectorizers = [
    TfidfVectorizer(),
    CountVectorizer()
]

# %% [markdown]
# # GridSearch implementation

# %%
models = {
    'RandomForest': {
        'model': RandomForestClassifier(),
        'params': {
            'n_estimators': [100, 150, 200],
            'max_depth': [None, 10, 20]
        }
    },
    'SVC': {
        'model': SVC(),
        'params': {
            'C': [1, 10],
            'kernel': ['linear', 'rbf']
        }
    },
    'MultinomialNB': {
        'model': MultinomialNB(),
        'params': {
            'alpha': [0.01, 1.0]
        }
    },
    'LogisticRegression': {
        'model': LogisticRegression(max_iter=1000),
        'params': {
            'C': [1, 10]
        }
    },
    'KNeighbors': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3, 5, 7]
        }
    },
    'DecisionTree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'max_depth': [None, 10, 20]
        }
    },
    'GradientBoosting': {
        'model': GradientBoostingClassifier(),
        'params': {
            'n_estimators': [100, 150, 200],
            'max_depth': [3, 5, 7]
        }
    },
    'AdaBoost': {
        'model': AdaBoostClassifier(),
        'params': {
            'n_estimators': [50, 100, 150]
        }
    },
    'SGD': {
        'model': SGDClassifier(),
        'params': {
            'alpha': [0.0001, 0.001]
        }
    }
}

# %%
results = {}

for seed in seeds:
    print(f"Processing seed: {seed}")
    for vectorizer in vectorizers:
        print(f"Processing vectorizer: {vectorizer}")
        for name, info in models.items():
            print(f"Processing model: {name}")
            model = info['model']
            param_grid = info['params']
            param_combinations = product(*param_grid.values())
            
            for combination in param_combinations:
                params = dict(zip(param_grid.keys(), combination))
                model.set_params(**params)

                print(f"Training {name} with params {params} and vectorizer {vectorizer}")
                pipeline = Pipeline([
                    ('vectorizer', vectorizer),
                    ('model', model)
                ])

                start = time.time()
                pipeline.fit(train['text'], train['label'])
                total_time = time.time() - start
                print(f"Training time: {total_time}")

                y_pred = pipeline.predict(val['text'])
                report = classification_report(val['label'], y_pred, output_dict=True)
                
                result_key = (seed, vectorizer, name, tuple(params.items()))
                results[result_key] = {
                    'params': params,
                    'training_time': total_time,
                    'classification_report': report
                }
# Out:
# Processing seed: 418380670049
# Processing vectorizer: TfidfVectorizer()
# Processing model: RandomForest
# Training RandomForest with params {'n_estimators': 100, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 16.534723043441772
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.626702070236206
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 1.3966021537780762
# Training RandomForest with params {'n_estimators': 150, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 23.289532899856567
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.775524377822876
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 1.8080103397369385
# Training RandomForest with params {'n_estimators': 200, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 31.576417922973633
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 1.1788678169250488
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 2.385974645614624
# Processing model: SVC
# Training SVC with params {'C': 1, 'kernel': 'linear'} and vectorizer TfidfVectorizer()
# Training time: 10.06120753288269
# Training SVC with params {'C': 1, 'kernel': 'rbf'} and vectorizer TfidfVectorizer()
# Training time: 15.888741493225098
# Training SVC with params {'C': 10, 'kernel': 'linear'} and vectorizer TfidfVectorizer()
# Training time: 17.685768365859985
# Training SVC with params {'C': 10, 'kernel': 'rbf'} and vectorizer TfidfVectorizer()
# Training time: 29.583155155181885
# Processing model: MultinomialNB
# Training MultinomialNB with params {'alpha': 0.01} and vectorizer TfidfVectorizer()
# Training time: 0.14972877502441406
# Training MultinomialNB with params {'alpha': 1.0} and vectorizer TfidfVectorizer()
# Training time: 0.14237093925476074
# Processing model: LogisticRegression
# Training LogisticRegression with params {'C': 1} and vectorizer TfidfVectorizer()
# Training time: 0.29885244369506836
# Training LogisticRegression with params {'C': 10} and vectorizer TfidfVectorizer()
# Training time: 0.3426542282104492
# Processing model: KNeighbors
# Training KNeighbors with params {'n_neighbors': 3} and vectorizer TfidfVectorizer()
# Training time: 0.11684441566467285
# Training KNeighbors with params {'n_neighbors': 5} and vectorizer TfidfVectorizer()
# Training time: 0.10739398002624512
# Training KNeighbors with params {'n_neighbors': 7} and vectorizer TfidfVectorizer()
# Training time: 0.1183481216430664
# Processing model: DecisionTree
# Training DecisionTree with params {'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 2.105926036834717
# Training DecisionTree with params {'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.3270864486694336
# Training DecisionTree with params {'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 0.5954673290252686
# Processing model: GradientBoosting
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 6.381851673126221
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 11.067589044570923
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 15.223615407943726
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 9.861002683639526
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 17.6077721118927
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 24.980318784713745
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 13.27496075630188
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 22.160486221313477
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 33.15008187294006
# Processing model: AdaBoost
# Training AdaBoost with params {'n_estimators': 50} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 1.7479774951934814
# Training AdaBoost with params {'n_estimators': 100} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 2.8582088947296143
# Training AdaBoost with params {'n_estimators': 150} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 4.271351099014282
# Processing model: SGD
# Training SGD with params {'alpha': 0.0001} and vectorizer TfidfVectorizer()
# Training time: 0.17654061317443848
# Training SGD with params {'alpha': 0.001} and vectorizer TfidfVectorizer()
# Training time: 0.15640568733215332
# Processing vectorizer: CountVectorizer()
# Processing model: RandomForest
# Training RandomForest with params {'n_estimators': 100, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 18.72861671447754
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.5713338851928711
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 1.2483413219451904
# Training RandomForest with params {'n_estimators': 150, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 27.840571641921997
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.8336763381958008
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 1.8757970333099365
# Training RandomForest with params {'n_estimators': 200, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 37.30528163909912
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 1.1363434791564941
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 2.408437967300415
# Processing model: SVC
# Training SVC with params {'C': 1, 'kernel': 'linear'} and vectorizer CountVectorizer()
# Training time: 12.747773885726929
# Training SVC with params {'C': 1, 'kernel': 'rbf'} and vectorizer CountVectorizer()
# Training time: 12.419787883758545
# Training SVC with params {'C': 10, 'kernel': 'linear'} and vectorizer CountVectorizer()
# Training time: 17.10861587524414
# Training SVC with params {'C': 10, 'kernel': 'rbf'} and vectorizer CountVectorizer()
# Training time: 26.335997104644775
# Processing model: MultinomialNB
# Training MultinomialNB with params {'alpha': 0.01} and vectorizer CountVectorizer()
# Training time: 0.13692736625671387
# Training MultinomialNB with params {'alpha': 1.0} and vectorizer CountVectorizer()
# Training time: 0.1509552001953125
# Processing model: LogisticRegression
# Training LogisticRegression with params {'C': 1} and vectorizer CountVectorizer()
# Training time: 0.4300844669342041
# Training LogisticRegression with params {'C': 10} and vectorizer CountVectorizer()
# Training time: 0.6332852840423584
# Processing model: KNeighbors
# Training KNeighbors with params {'n_neighbors': 3} and vectorizer CountVectorizer()
# Training time: 0.10548520088195801
# Training KNeighbors with params {'n_neighbors': 5} and vectorizer CountVectorizer()
# Training time: 0.12445878982543945
# Training KNeighbors with params {'n_neighbors': 7} and vectorizer CountVectorizer()
# Training time: 0.10363554954528809
# Processing model: DecisionTree
# Training DecisionTree with params {'max_depth': None} and vectorizer CountVectorizer()
# Training time: 2.0335609912872314
# Training DecisionTree with params {'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.28511667251586914
# Training DecisionTree with params {'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 0.5083732604980469
# Processing model: GradientBoosting
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 3.9424548149108887
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 6.290070533752441
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 10.00692868232727
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 5.53261399269104
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 9.747068881988525
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 13.300541877746582
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 7.159118175506592
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 12.787914276123047
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 17.958343982696533
# Processing model: AdaBoost
# Training AdaBoost with params {'n_estimators': 50} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 0.9764914512634277
# Training AdaBoost with params {'n_estimators': 100} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 1.800144910812378
# Training AdaBoost with params {'n_estimators': 150} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 2.5899338722229004
# Processing model: SGD
# Training SGD with params {'alpha': 0.0001} and vectorizer CountVectorizer()
# Training time: 0.20014691352844238
# Training SGD with params {'alpha': 0.001} and vectorizer CountVectorizer()
# Training time: 0.1633446216583252
# Processing seed: 5522499
# Processing vectorizer: TfidfVectorizer()
# Processing model: RandomForest
# Training RandomForest with params {'n_estimators': 100, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 15.47559142112732
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.6708724498748779
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 1.391667366027832
# Training RandomForest with params {'n_estimators': 150, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 23.12375569343567
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.972358226776123
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 2.0530600547790527
# Training RandomForest with params {'n_estimators': 200, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 32.12046432495117
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 1.204993486404419
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 2.7202250957489014
# Processing model: SVC
# Training SVC with params {'C': 1, 'kernel': 'linear'} and vectorizer TfidfVectorizer()
# Training time: 10.43686056137085
# Training SVC with params {'C': 1, 'kernel': 'rbf'} and vectorizer TfidfVectorizer()
# Training time: 18.022931575775146
# Training SVC with params {'C': 10, 'kernel': 'linear'} and vectorizer TfidfVectorizer()
# Training time: 19.57818102836609
# Training SVC with params {'C': 10, 'kernel': 'rbf'} and vectorizer TfidfVectorizer()
# Training time: 30.910728693008423
# Processing model: MultinomialNB
# Training MultinomialNB with params {'alpha': 0.01} and vectorizer TfidfVectorizer()
# Training time: 0.13437747955322266
# Training MultinomialNB with params {'alpha': 1.0} and vectorizer TfidfVectorizer()
# Training time: 0.14821267127990723
# Processing model: LogisticRegression
# Training LogisticRegression with params {'C': 1} and vectorizer TfidfVectorizer()
# Training time: 0.2935776710510254
# Training LogisticRegression with params {'C': 10} and vectorizer TfidfVectorizer()
# Training time: 0.33335089683532715
# Processing model: KNeighbors
# Training KNeighbors with params {'n_neighbors': 3} and vectorizer TfidfVectorizer()
# Training time: 0.11280298233032227
# Training KNeighbors with params {'n_neighbors': 5} and vectorizer TfidfVectorizer()
# Training time: 0.14724183082580566
# Training KNeighbors with params {'n_neighbors': 7} and vectorizer TfidfVectorizer()
# Training time: 0.10811519622802734
# Processing model: DecisionTree
# Training DecisionTree with params {'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 2.1779325008392334
# Training DecisionTree with params {'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.3798685073852539
# Training DecisionTree with params {'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 0.6404669284820557
# Processing model: GradientBoosting
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 6.843557596206665
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 11.484846353530884
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 16.459604501724243
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 9.792672157287598
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 16.887654542922974
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 23.813146114349365
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 12.663167953491211
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 21.69046926498413
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 1023.1222071647644
# Processing model: AdaBoost
# Training AdaBoost with params {'n_estimators': 50} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 0.985710620880127
# Training AdaBoost with params {'n_estimators': 100} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 2.5080273151397705
# Training AdaBoost with params {'n_estimators': 150} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 4.884032487869263
# Processing model: SGD
# Training SGD with params {'alpha': 0.0001} and vectorizer TfidfVectorizer()
# Training time: 0.1859750747680664
# Training SGD with params {'alpha': 0.001} and vectorizer TfidfVectorizer()
# Training time: 0.1650841236114502
# Processing vectorizer: CountVectorizer()
# Processing model: RandomForest
# Training RandomForest with params {'n_estimators': 100, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 18.931056261062622
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.5125863552093506
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 1.0999157428741455
# Training RandomForest with params {'n_estimators': 150, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 27.64098834991455
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.8672928810119629
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 1.7702715396881104
# Training RandomForest with params {'n_estimators': 200, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 37.13378024101257
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.9944632053375244
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 2.402808666229248
# Processing model: SVC
# Training SVC with params {'C': 1, 'kernel': 'linear'} and vectorizer CountVectorizer()
# Training time: 12.989372730255127
# Training SVC with params {'C': 1, 'kernel': 'rbf'} and vectorizer CountVectorizer()
# Training time: 12.459445476531982
# Training SVC with params {'C': 10, 'kernel': 'linear'} and vectorizer CountVectorizer()
# Training time: 15.294822454452515
# Training SVC with params {'C': 10, 'kernel': 'rbf'} and vectorizer CountVectorizer()
# Training time: 24.954529762268066
# Processing model: MultinomialNB
# Training MultinomialNB with params {'alpha': 0.01} and vectorizer CountVectorizer()
# Training time: 0.11422896385192871
# Training MultinomialNB with params {'alpha': 1.0} and vectorizer CountVectorizer()
# Training time: 0.1094808578491211
# Processing model: LogisticRegression
# Training LogisticRegression with params {'C': 1} and vectorizer CountVectorizer()
# Training time: 0.45316171646118164
# Training LogisticRegression with params {'C': 10} and vectorizer CountVectorizer()
# Training time: 0.6259431838989258
# Processing model: KNeighbors
# Training KNeighbors with params {'n_neighbors': 3} and vectorizer CountVectorizer()
# Training time: 0.13490629196166992
# Training KNeighbors with params {'n_neighbors': 5} and vectorizer CountVectorizer()
# Training time: 0.10672378540039062
# Training KNeighbors with params {'n_neighbors': 7} and vectorizer CountVectorizer()
# Training time: 0.1179494857788086
# Processing model: DecisionTree
# Training DecisionTree with params {'max_depth': None} and vectorizer CountVectorizer()
# Training time: 2.019078016281128
# Training DecisionTree with params {'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.3103799819946289
# Training DecisionTree with params {'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 0.4524376392364502
# Processing model: GradientBoosting
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 3.581484794616699
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 5.939670085906982
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 8.729207992553711
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 4.9679505825042725
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 8.705949068069458
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 13.375042915344238
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 7.179655313491821
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 12.735106945037842
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 17.675148725509644
# Processing model: AdaBoost
# Training AdaBoost with params {'n_estimators': 50} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 1.1094961166381836
# Training AdaBoost with params {'n_estimators': 100} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 1.8664708137512207
# Training AdaBoost with params {'n_estimators': 150} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 2.9118354320526123
# Processing model: SGD
# Training SGD with params {'alpha': 0.0001} and vectorizer CountVectorizer()
# Training time: 0.2039778232574463
# Training SGD with params {'alpha': 0.001} and vectorizer CountVectorizer()
# Training time: 0.16692042350769043
# Processing seed: 29114468376207731
# Processing vectorizer: TfidfVectorizer()
# Processing model: RandomForest
# Training RandomForest with params {'n_estimators': 100, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 15.74964165687561
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.680387020111084
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 1.2430059909820557
# Training RandomForest with params {'n_estimators': 150, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 22.361841201782227
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.939460277557373
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 1.8980917930603027
# Training RandomForest with params {'n_estimators': 200, 'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 31.874858379364014
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 1.1342148780822754
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 2.470323324203491
# Processing model: SVC
# Training SVC with params {'C': 1, 'kernel': 'linear'} and vectorizer TfidfVectorizer()
# Training time: 10.82494831085205
# Training SVC with params {'C': 1, 'kernel': 'rbf'} and vectorizer TfidfVectorizer()
# Training time: 15.73686695098877
# Training SVC with params {'C': 10, 'kernel': 'linear'} and vectorizer TfidfVectorizer()
# Training time: 18.195698499679565
# Training SVC with params {'C': 10, 'kernel': 'rbf'} and vectorizer TfidfVectorizer()
# Training time: 29.01217246055603
# Processing model: MultinomialNB
# Training MultinomialNB with params {'alpha': 0.01} and vectorizer TfidfVectorizer()
# Training time: 0.12781095504760742
# Training MultinomialNB with params {'alpha': 1.0} and vectorizer TfidfVectorizer()
# Training time: 0.19154930114746094
# Processing model: LogisticRegression
# Training LogisticRegression with params {'C': 1} and vectorizer TfidfVectorizer()
# Training time: 0.7765138149261475
# Training LogisticRegression with params {'C': 10} and vectorizer TfidfVectorizer()
# Training time: 0.3447542190551758
# Processing model: KNeighbors
# Training KNeighbors with params {'n_neighbors': 3} and vectorizer TfidfVectorizer()
# Training time: 0.14864611625671387
# Training KNeighbors with params {'n_neighbors': 5} and vectorizer TfidfVectorizer()
# Training time: 0.11104989051818848
# Training KNeighbors with params {'n_neighbors': 7} and vectorizer TfidfVectorizer()
# Training time: 0.12269306182861328
# Processing model: DecisionTree
# Training DecisionTree with params {'max_depth': None} and vectorizer TfidfVectorizer()
# Training time: 2.179701566696167
# Training DecisionTree with params {'max_depth': 10} and vectorizer TfidfVectorizer()
# Training time: 0.3671107292175293
# Training DecisionTree with params {'max_depth': 20} and vectorizer TfidfVectorizer()
# Training time: 0.6373038291931152
# Processing model: GradientBoosting
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 6.186296224594116
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 11.00016164779663
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 15.835187911987305
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 10.98943305015564
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 17.806178331375122
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 25.187049388885498
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 3} and vectorizer TfidfVectorizer()
# Training time: 13.5972158908844
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 5} and vectorizer TfidfVectorizer()
# Training time: 23.160889387130737
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 7} and vectorizer TfidfVectorizer()
# Training time: 32.535038471221924
# Processing model: AdaBoost
# Training AdaBoost with params {'n_estimators': 50} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 1.5221259593963623
# Training AdaBoost with params {'n_estimators': 100} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 3.2236428260803223
# Training AdaBoost with params {'n_estimators': 150} and vectorizer TfidfVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 4.700650453567505
# Processing model: SGD
# Training SGD with params {'alpha': 0.0001} and vectorizer TfidfVectorizer()
# Training time: 0.15793418884277344
# Training SGD with params {'alpha': 0.001} and vectorizer TfidfVectorizer()
# Training time: 0.1625232696533203
# Processing vectorizer: CountVectorizer()
# Processing model: RandomForest
# Training RandomForest with params {'n_estimators': 100, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 18.012313842773438
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.5814740657806396
# Training RandomForest with params {'n_estimators': 100, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 1.2891592979431152
# Training RandomForest with params {'n_estimators': 150, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 27.93504023551941
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.8277044296264648
# Training RandomForest with params {'n_estimators': 150, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 2.0051629543304443
# Training RandomForest with params {'n_estimators': 200, 'max_depth': None} and vectorizer CountVectorizer()
# Training time: 36.93462896347046
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 1.0989882946014404
# Training RandomForest with params {'n_estimators': 200, 'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 2.41711163520813
# Processing model: SVC
# Training SVC with params {'C': 1, 'kernel': 'linear'} and vectorizer CountVectorizer()
# Training time: 12.549921751022339
# Training SVC with params {'C': 1, 'kernel': 'rbf'} and vectorizer CountVectorizer()
# Training time: 12.885313749313354
# Training SVC with params {'C': 10, 'kernel': 'linear'} and vectorizer CountVectorizer()
# Training time: 16.59241247177124
# Training SVC with params {'C': 10, 'kernel': 'rbf'} and vectorizer CountVectorizer()
# Training time: 27.39398217201233
# Processing model: MultinomialNB
# Training MultinomialNB with params {'alpha': 0.01} and vectorizer CountVectorizer()
# Training time: 0.15421533584594727
# Training MultinomialNB with params {'alpha': 1.0} and vectorizer CountVectorizer()
# Training time: 0.1393880844116211
# Processing model: LogisticRegression
# Training LogisticRegression with params {'C': 1} and vectorizer CountVectorizer()
# Training time: 0.47182488441467285
# Training LogisticRegression with params {'C': 10} and vectorizer CountVectorizer()
# Training time: 0.6396346092224121
# Processing model: KNeighbors
# Training KNeighbors with params {'n_neighbors': 3} and vectorizer CountVectorizer()
# Training time: 0.1102607250213623
# Training KNeighbors with params {'n_neighbors': 5} and vectorizer CountVectorizer()
# Training time: 0.13296890258789062
# Training KNeighbors with params {'n_neighbors': 7} and vectorizer CountVectorizer()
# Training time: 0.15309619903564453
# Processing model: DecisionTree
# Training DecisionTree with params {'max_depth': None} and vectorizer CountVectorizer()
# Training time: 2.2777867317199707
# Training DecisionTree with params {'max_depth': 10} and vectorizer CountVectorizer()
# Training time: 0.3465442657470703
# Training DecisionTree with params {'max_depth': 20} and vectorizer CountVectorizer()
# Training time: 0.6479809284210205
# Processing model: GradientBoosting
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 3.928471088409424
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 7.393103122711182
# Training GradientBoosting with params {'n_estimators': 100, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 10.746104955673218
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 5.954894065856934
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 10.63064956665039
# Training GradientBoosting with params {'n_estimators': 150, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 15.103183507919312
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 3} and vectorizer CountVectorizer()
# Training time: 7.541140556335449
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 5} and vectorizer CountVectorizer()
# Training time: 13.240647077560425
# Training GradientBoosting with params {'n_estimators': 200, 'max_depth': 7} and vectorizer CountVectorizer()
# Training time: 18.477378606796265
# Processing model: AdaBoost
# Training AdaBoost with params {'n_estimators': 50} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 0.964245080947876
# Training AdaBoost with params {'n_estimators': 100} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 1.8461363315582275
# Training AdaBoost with params {'n_estimators': 150} and vectorizer CountVectorizer()
# c:\Users\rafae\Documents\TCC\venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Training time: 2.8862392902374268
# Processing model: SGD
# Training SGD with params {'alpha': 0.0001} and vectorizer CountVectorizer()
# Training time: 0.20819878578186035
# Training SGD with params {'alpha': 0.001} and vectorizer CountVectorizer()
# Training time: 0.21209049224853516

# %%
# convert results to df
results
# Out:
# {(418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 100),
#    ('max_depth', None))): {'params': {'n_estimators': 100, 'max_depth': None},
#   'training_time': 16.534723043441772,
#   'classification_report': {'0': {'precision': 0.7223880597014926,
#     'recall': 0.8446771378708552,
#     'f1-score': 0.7787610619469026,
#     'support': 573.0},
#    '1': {'precision': 0.7303030303030303,
#     'recall': 0.5644028103044496,
#     'f1-score': 0.6367239101717305,
#     'support': 427.0},
#    'accuracy': 0.725,
#    'macro avg': {'precision': 0.7263455450022615,
#     'recall': 0.7045399740876523,
#     'f1-score': 0.7077424860593166,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7257677521483492,
#     'recall': 0.725,
#     'f1-score': 0.7181111981389041,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 100), ('max_depth', 10))): {'params': {'n_estimators': 100,
#    'max_depth': 10},
#   'training_time': 0.626702070236206,
#   'classification_report': {'0': {'precision': 0.6027689030883919,
#     'recall': 0.987783595113438,
#     'f1-score': 0.7486772486772487,
#     'support': 573.0},
#    '1': {'precision': 0.8852459016393442,
#     'recall': 0.12646370023419204,
#     'f1-score': 0.22131147540983606,
#     'support': 427.0},
#    'accuracy': 0.62,
#    'macro avg': {'precision': 0.7440074023638681,
#     'recall': 0.5571236476738151,
#     'f1-score': 0.4849943620435424,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7233865814696485,
#     'recall': 0.62,
#     'f1-score': 0.5234920634920635,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 100), ('max_depth', 20))): {'params': {'n_estimators': 100,
#    'max_depth': 20},
#   'training_time': 1.3966021537780762,
#   'classification_report': {'0': {'precision': 0.6360505166475315,
#     'recall': 0.9668411867364747,
#     'f1-score': 0.7673130193905817,
#     'support': 573.0},
#    '1': {'precision': 0.8527131782945736,
#     'recall': 0.2576112412177986,
#     'f1-score': 0.39568345323741005,
#     'support': 427.0},
#    'accuracy': 0.664,
#    'macro avg': {'precision': 0.7443818474710526,
#     'recall': 0.6122262139771366,
#     'f1-score': 0.5814982363139959,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7285654731708184,
#     'recall': 0.664,
#     'f1-score': 0.6086271946431774,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 150),
#    ('max_depth', None))): {'params': {'n_estimators': 150, 'max_depth': None},
#   'training_time': 23.289532899856567,
#   'classification_report': {'0': {'precision': 0.7249626307922272,
#     'recall': 0.8464223385689355,
#     'f1-score': 0.7809983896940419,
#     'support': 573.0},
#    '1': {'precision': 0.7341389728096677,
#     'recall': 0.5690866510538641,
#     'f1-score': 0.6411609498680739,
#     'support': 427.0},
#    'accuracy': 0.728,
#    'macro avg': {'precision': 0.7295508018009474,
#     'recall': 0.7077544948113998,
#     'f1-score': 0.711079669781058,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7288809288336743,
#     'recall': 0.728,
#     'f1-score': 0.7212878028883536,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 150), ('max_depth', 10))): {'params': {'n_estimators': 150,
#    'max_depth': 10},
#   'training_time': 0.775524377822876,
#   'classification_report': {'0': {'precision': 0.59436913451512,
#     'recall': 0.9947643979057592,
#     'f1-score': 0.7441253263707572,
#     'support': 573.0},
#    '1': {'precision': 0.926829268292683,
#     'recall': 0.08899297423887588,
#     'f1-score': 0.1623931623931624,
#     'support': 427.0},
#    'accuracy': 0.608,
#    'macro avg': {'precision': 0.7605992014039015,
#     'recall': 0.5418786860723176,
#     'f1-score': 0.4532592443819598,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7363296116381394,
#     'recall': 0.608,
#     'f1-score': 0.4957256923523242,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 150), ('max_depth', 20))): {'params': {'n_estimators': 150,
#    'max_depth': 20},
#   'training_time': 1.8080103397369385,
#   'classification_report': {'0': {'precision': 0.649643705463183,
#     'recall': 0.9546247818499127,
#     'f1-score': 0.7731448763250883,
#     'support': 573.0},
#    '1': {'precision': 0.8354430379746836,
#     'recall': 0.3091334894613583,
#     'f1-score': 0.4512820512820513,
#     'support': 427.0},
#    'accuracy': 0.679,
#    'macro avg': {'precision': 0.7425433717189333,
#     'recall': 0.6318791356556355,
#     'f1-score': 0.6122134638035698,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7289800204455937,
#     'recall': 0.679,
#     'f1-score': 0.6357094500317115,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 200),
#    ('max_depth', None))): {'params': {'n_estimators': 200, 'max_depth': None},
#   'training_time': 31.576417922973633,
#   'classification_report': {'0': {'precision': 0.7149122807017544,
#     'recall': 0.8534031413612565,
#     'f1-score': 0.7780429594272077,
#     'support': 573.0},
#    '1': {'precision': 0.7341772151898734,
#     'recall': 0.5433255269320844,
#     'f1-score': 0.6244952893674294,
#     'support': 427.0},
#    'accuracy': 0.721,
#    'macro avg': {'precision': 0.7245447479458139,
#     'recall': 0.6983643341466704,
#     'f1-score': 0.7012691243973186,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7231384077281812,
#     'recall': 0.721,
#     'f1-score': 0.7124781043116822,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 200), ('max_depth', 10))): {'params': {'n_estimators': 200,
#    'max_depth': 10},
#   'training_time': 1.1788678169250488,
#   'classification_report': {'0': {'precision': 0.5923236514522822,
#     'recall': 0.9965095986038395,
#     'f1-score': 0.7430058555627846,
#     'support': 573.0},
#    '1': {'precision': 0.9444444444444444,
#     'recall': 0.07962529274004684,
#     'f1-score': 0.1468682505399568,
#     'support': 427.0},
#    'accuracy': 0.605,
#    'macro avg': {'precision': 0.7683840479483632,
#     'recall': 0.5380674456719432,
#     'f1-score': 0.4449370530513707,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7426792300599354,
#     'recall': 0.605,
#     'f1-score': 0.4884550982180372,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'RandomForest',
#   (('n_estimators', 200), ('max_depth', 20))): {'params': {'n_estimators': 200,
#    'max_depth': 20},
#   'training_time': 2.385974645614624,
#   'classification_report': {'0': {'precision': 0.65311004784689,
#     'recall': 0.9528795811518325,
#     'f1-score': 0.7750177430801988,
#     'support': 573.0},
#    '1': {'precision': 0.8353658536585366,
#     'recall': 0.32084309133489464,
#     'f1-score': 0.46362098138747887,
#     'support': 427.0},
#    'accuracy': 0.683,
#    'macro avg': {'precision': 0.7442379507527133,
#     'recall': 0.6368613362433635,
#     'f1-score': 0.6193193622338389,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7309332769284631,
#     'recall': 0.683,
#     'f1-score': 0.6420513258374074,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'SVC',
#   (('C', 1), ('kernel', 'linear'))): {'params': {'C': 1,
#    'kernel': 'linear'}, 'training_time': 10.06120753288269, 'classification_report': {'0': {'precision': 0.7278688524590164,
#     'recall': 0.774869109947644,
#     'f1-score': 0.7506339814032121,
#     'support': 573.0},
#    '1': {'precision': 0.6692307692307692,
#     'recall': 0.6112412177985949,
#     'f1-score': 0.6389228886168911,
#     'support': 427.0},
#    'accuracy': 0.705,
#    'macro avg': {'precision': 0.6985498108448929,
#     'recall': 0.6930551638731195,
#     'f1-score': 0.6947784350100517,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7028303909205549,
#     'recall': 0.705,
#     'f1-score': 0.702933344783453,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'SVC',
#   (('C', 1), ('kernel', 'rbf'))): {'params': {'C': 1,
#    'kernel': 'rbf'}, 'training_time': 15.888741493225098, 'classification_report': {'0': {'precision': 0.7272727272727273,
#     'recall': 0.8516579406631762,
#     'f1-score': 0.7845659163987139,
#     'support': 573.0},
#    '1': {'precision': 0.7416413373860182,
#     'recall': 0.5714285714285714,
#     'f1-score': 0.6455026455026455,
#     'support': 427.0},
#    'accuracy': 0.732,
#    'macro avg': {'precision': 0.7344570323293728,
#     'recall': 0.7115432560458739,
#     'f1-score': 0.7150342809506797,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7334081237911025,
#     'recall': 0.732,
#     'f1-score': 0.7251858997260927,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'SVC',
#   (('C', 10), ('kernel', 'linear'))): {'params': {'C': 10,
#    'kernel': 'linear'}, 'training_time': 17.685768365859985, 'classification_report': {'0': {'precision': 0.7309941520467836,
#     'recall': 0.6544502617801047,
#     'f1-score': 0.6906077348066298,
#     'support': 573.0},
#    '1': {'precision': 0.5934291581108829,
#     'recall': 0.6768149882903981,
#     'f1-score': 0.6323851203501094,
#     'support': 427.0},
#    'accuracy': 0.664,
#    'macro avg': {'precision': 0.6622116550788333,
#     'recall': 0.6656326250352513,
#     'f1-score': 0.6614964275783697,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6722538996361541,
#     'recall': 0.664,
#     'f1-score': 0.6657466784336956,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'SVC',
#   (('C', 10), ('kernel', 'rbf'))): {'params': {'C': 10,
#    'kernel': 'rbf'}, 'training_time': 29.583155155181885, 'classification_report': {'0': {'precision': 0.7345276872964169,
#     'recall': 0.787085514834206,
#     'f1-score': 0.7598989048020219,
#     'support': 573.0},
#    '1': {'precision': 0.6839378238341969,
#     'recall': 0.6182669789227166,
#     'f1-score': 0.6494464944649446,
#     'support': 427.0},
#    'accuracy': 0.715,
#    'macro avg': {'precision': 0.7092327555653068,
#     'recall': 0.7026762468784613,
#     'f1-score': 0.7046726996334833,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.712925815598049,
#     'recall': 0.715,
#     'f1-score': 0.71273572558809,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'MultinomialNB',
#   (('alpha',
#     0.01),)): {'params': {'alpha': 0.01}, 'training_time': 0.14972877502441406, 'classification_report': {'0': {'precision': 0.7407407407407407,
#     'recall': 0.6631762652705061,
#     'f1-score': 0.6998158379373849,
#     'support': 573.0},
#    '1': {'precision': 0.6036960985626283,
#     'recall': 0.6885245901639344,
#     'f1-score': 0.6433260393873085,
#     'support': 427.0},
#    'accuracy': 0.674,
#    'macro avg': {'precision': 0.6722184196516845,
#     'recall': 0.6758504277172203,
#     'f1-score': 0.6715709386623467,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6822226785306866,
#     'recall': 0.674,
#     'f1-score': 0.6756946939565023,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'MultinomialNB',
#   (('alpha',
#     1.0),)): {'params': {'alpha': 1.0}, 'training_time': 0.14237093925476074, 'classification_report': {'0': {'precision': 0.7209653092006033,
#     'recall': 0.8342059336823735,
#     'f1-score': 0.7734627831715211,
#     'support': 573.0},
#    '1': {'precision': 0.7181008902077152,
#     'recall': 0.5667447306791569,
#     'f1-score': 0.6335078534031413,
#     'support': 427.0},
#    'accuracy': 0.72,
#    'macro avg': {'precision': 0.7195330997041592,
#     'recall': 0.7004753321807652,
#     'f1-score': 0.7034853182873312,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7197422022906401,
#     'recall': 0.72,
#     'f1-score': 0.7137020281604229,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'LogisticRegression',
#   (('C',
#     1),)): {'params': {'C': 1}, 'training_time': 0.29885244369506836, 'classification_report': {'0': {'precision': 0.7262996941896025,
#     'recall': 0.8289703315881326,
#     'f1-score': 0.7742461287693562,
#     'support': 573.0},
#    '1': {'precision': 0.7167630057803468,
#     'recall': 0.5807962529274004,
#     'f1-score': 0.6416558861578266,
#     'support': 427.0},
#    'accuracy': 0.723,
#    'macro avg': {'precision': 0.7215313499849747,
#     'recall': 0.7048832922577666,
#     'f1-score': 0.7079510074635914,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7222275282388503,
#     'recall': 0.723,
#     'f1-score': 0.717630095174233,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'LogisticRegression',
#   (('C',
#     10),)): {'params': {'C': 10}, 'training_time': 0.3426542282104492, 'classification_report': {'0': {'precision': 0.7332185886402753,
#     'recall': 0.743455497382199,
#     'f1-score': 0.7383015597920277,
#     'support': 573.0},
#    '1': {'precision': 0.649164677804296,
#     'recall': 0.6370023419203747,
#     'f1-score': 0.6430260047281324,
#     'support': 427.0},
#    'accuracy': 0.698,
#    'macro avg': {'precision': 0.6911916332222856,
#     'recall': 0.6902289196512869,
#     'f1-score': 0.6906637822600801,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6973275687133121,
#     'recall': 0.698,
#     'f1-score': 0.6976188977797444,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     3),)): {'params': {'n_neighbors': 3}, 'training_time': 0.11684441566467285, 'classification_report': {'0': {'precision': 0.5852390852390852,
#     'recall': 0.9825479930191972,
#     'f1-score': 0.7335504885993486,
#     'support': 573.0},
#    '1': {'precision': 0.7368421052631579,
#     'recall': 0.06557377049180328,
#     'f1-score': 0.12043010752688173,
#     'support': 427.0},
#    'accuracy': 0.591,
#    'macro avg': {'precision': 0.6610405952511216,
#     'recall': 0.5240608817555003,
#     'f1-score': 0.42699029806311517,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6499735747893642,
#     'recall': 0.591,
#     'f1-score': 0.47174808588140527,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     5),)): {'params': {'n_neighbors': 5}, 'training_time': 0.10739398002624512, 'classification_report': {'0': {'precision': 0.5801838610827375,
#     'recall': 0.9912739965095986,
#     'f1-score': 0.7319587628865979,
#     'support': 573.0},
#    '1': {'precision': 0.7619047619047619,
#     'recall': 0.03747072599531616,
#     'f1-score': 0.07142857142857142,
#     'support': 427.0},
#    'accuracy': 0.584,
#    'macro avg': {'precision': 0.6710443114937497,
#     'recall': 0.5143723612524573,
#     'f1-score': 0.40169366715758464,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6577786857337419,
#     'recall': 0.584,
#     'f1-score': 0.4499123711340206,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     7),)): {'params': {'n_neighbors': 7}, 'training_time': 0.1183481216430664, 'classification_report': {'0': {'precision': 0.5766497461928934,
#     'recall': 0.9912739965095986,
#     'f1-score': 0.7291399229781772,
#     'support': 573.0},
#    '1': {'precision': 0.6666666666666666,
#     'recall': 0.0234192037470726,
#     'f1-score': 0.04524886877828054,
#     'support': 427.0},
#    'accuracy': 0.578,
#    'macro avg': {'precision': 0.62165820642978,
#     'recall': 0.5073466001283355,
#     'f1-score': 0.38719439587822885,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6150869712351946,
#     'recall': 0.578,
#     'f1-score': 0.4371184428348213,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'DecisionTree',
#   (('max_depth',
#     None),)): {'params': {'max_depth': None}, 'training_time': 2.105926036834717, 'classification_report': {'0': {'precision': 0.7211367673179396,
#     'recall': 0.7085514834205934,
#     'f1-score': 0.7147887323943662,
#     'support': 573.0},
#    '1': {'precision': 0.6178489702517163,
#     'recall': 0.6323185011709602,
#     'f1-score': 0.625,
#     'support': 427.0},
#    'accuracy': 0.676,
#    'macro avg': {'precision': 0.6694928687848279,
#     'recall': 0.6704349922957769,
#     'f1-score': 0.6698943661971831,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6770328779706621,
#     'recall': 0.676,
#     'f1-score': 0.6764489436619718,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'DecisionTree',
#   (('max_depth',
#     10),)): {'params': {'max_depth': 10}, 'training_time': 0.3270864486694336, 'classification_report': {'0': {'precision': 0.6553524804177546,
#     'recall': 0.8760907504363001,
#     'f1-score': 0.7498132935026139,
#     'support': 573.0},
#    '1': {'precision': 0.6965811965811965,
#     'recall': 0.38173302107728335,
#     'f1-score': 0.49319213313161875,
#     'support': 427.0},
#    'accuracy': 0.665,
#    'macro avg': {'precision': 0.6759668384994756,
#     'recall': 0.6289118857567917,
#     'f1-score': 0.6215027133171164,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6729571422195443,
#     'recall': 0.665,
#     'f1-score': 0.640236058024199,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'DecisionTree',
#   (('max_depth',
#     20),)): {'params': {'max_depth': 20}, 'training_time': 0.5954673290252686, 'classification_report': {'0': {'precision': 0.6928571428571428,
#     'recall': 0.8464223385689355,
#     'f1-score': 0.7619795758051846,
#     'support': 573.0},
#    '1': {'precision': 0.7066666666666667,
#     'recall': 0.4964871194379391,
#     'f1-score': 0.5832187070151307,
#     'support': 427.0},
#    'accuracy': 0.697,
#    'macro avg': {'precision': 0.6997619047619048,
#     'recall': 0.6714547290034373,
#     'f1-score': 0.6725991414101576,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6987538095238095,
#     'recall': 0.697,
#     'f1-score': 0.6856486848318316,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 3))): {'params': {'n_estimators': 100,
#    'max_depth': 3},
#   'training_time': 6.381851673126221,
#   'classification_report': {'0': {'precision': 0.6894736842105263,
#     'recall': 0.9144851657940664,
#     'f1-score': 0.7861965491372843,
#     'support': 573.0},
#    '1': {'precision': 0.7958333333333333,
#     'recall': 0.44730679156908665,
#     'f1-score': 0.5727136431784108,
#     'support': 427.0},
#    'accuracy': 0.715,
#    'macro avg': {'precision': 0.7426535087719298,
#     'recall': 0.6808959786815765,
#     'f1-score': 0.6794550961578476,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.734889254385965,
#     'recall': 0.715,
#     'f1-score': 0.6950393482928453,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 5))): {'params': {'n_estimators': 100,
#    'max_depth': 5},
#   'training_time': 11.067589044570923,
#   'classification_report': {'0': {'precision': 0.6956521739130435,
#     'recall': 0.893542757417103,
#     'f1-score': 0.7822765469824293,
#     'support': 573.0},
#    '1': {'precision': 0.7689393939393939,
#     'recall': 0.47540983606557374,
#     'f1-score': 0.5875542691751086,
#     'support': 427.0},
#    'accuracy': 0.715,
#    'macro avg': {'precision': 0.7322957839262187,
#     'recall': 0.6844762967413384,
#     'f1-score': 0.6849154080787689,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.726945816864295,
#     'recall': 0.715,
#     'f1-score': 0.6991301343587033,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 7))): {'params': {'n_estimators': 100,
#    'max_depth': 7},
#   'training_time': 15.223615407943726,
#   'classification_report': {'0': {'precision': 0.6976090014064698,
#     'recall': 0.8656195462478184,
#     'f1-score': 0.7725856697819314,
#     'support': 573.0},
#    '1': {'precision': 0.7335640138408305,
#     'recall': 0.4964871194379391,
#     'f1-score': 0.5921787709497207,
#     'support': 427.0},
#    'accuracy': 0.708,
#    'macro avg': {'precision': 0.7155865076236501,
#     'recall': 0.6810533328428787,
#     'f1-score': 0.6823822203658261,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7129617917159418,
#     'recall': 0.708,
#     'f1-score': 0.6955519239805774,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 150), ('max_depth', 3))): {'params': {'n_estimators': 150,
#    'max_depth': 3},
#   'training_time': 9.861002683639526,
#   'classification_report': {'0': {'precision': 0.6940700808625337,
#     'recall': 0.8987783595113438,
#     'f1-score': 0.7832699619771863,
#     'support': 573.0},
#    '1': {'precision': 0.7751937984496124,
#     'recall': 0.468384074941452,
#     'f1-score': 0.583941605839416,
#     'support': 427.0},
#    'accuracy': 0.715,
#    'macro avg': {'precision': 0.7346319396560731,
#     'recall': 0.6835812172263979,
#     'f1-score': 0.6836057839083012,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7287099082722164,
#     'recall': 0.715,
#     'f1-score': 0.6981567539063585,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 150), ('max_depth', 5))): {'params': {'n_estimators': 150,
#    'max_depth': 5},
#   'training_time': 17.6077721118927,
#   'classification_report': {'0': {'precision': 0.6944444444444444,
#     'recall': 0.8726003490401396,
#     'f1-score': 0.7733952049497294,
#     'support': 573.0},
#    '1': {'precision': 0.7392857142857143,
#     'recall': 0.4847775175644028,
#     'f1-score': 0.5855728429985856,
#     'support': 427.0},
#    'accuracy': 0.707,
#    'macro avg': {'precision': 0.7168650793650794,
#     'recall': 0.6786889333022712,
#     'f1-score': 0.6794840239741575,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7135916666666667,
#     'recall': 0.707,
#     'f1-score': 0.693195056396591,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 150), ('max_depth', 7))): {'params': {'n_estimators': 150,
#    'max_depth': 7},
#   'training_time': 24.980318784713745,
#   'classification_report': {'0': {'precision': 0.6990014265335235,
#     'recall': 0.8551483420593369,
#     'f1-score': 0.7692307692307693,
#     'support': 573.0},
#    '1': {'precision': 0.7224080267558528,
#     'recall': 0.5058548009367682,
#     'f1-score': 0.5950413223140496,
#     'support': 427.0},
#    'accuracy': 0.706,
#    'macro avg': {'precision': 0.7107047266446882,
#     'recall': 0.6805015714980525,
#     'f1-score': 0.6821360457724095,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7089960448284581,
#     'recall': 0.706,
#     'f1-score': 0.69485187539733,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 200), ('max_depth', 3))): {'params': {'n_estimators': 200,
#    'max_depth': 3},
#   'training_time': 13.27496075630188,
#   'classification_report': {'0': {'precision': 0.694708276797829,
#     'recall': 0.893542757417103,
#     'f1-score': 0.7816793893129771,
#     'support': 573.0},
#    '1': {'precision': 0.7680608365019012,
#     'recall': 0.47306791569086654,
#     'f1-score': 0.5855072463768116,
#     'support': 427.0},
#    'accuracy': 0.714,
#    'macro avg': {'precision': 0.7313845566498651,
#     'recall': 0.6833053365539847,
#     'f1-score': 0.6835933178448943,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7260298197914679,
#     'recall': 0.714,
#     'f1-score': 0.6979138842792345,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 200), ('max_depth', 5))): {'params': {'n_estimators': 200,
#    'max_depth': 5},
#   'training_time': 22.160486221313477,
#   'classification_report': {'0': {'precision': 0.7021276595744681,
#     'recall': 0.8638743455497382,
#     'f1-score': 0.7746478873239436,
#     'support': 573.0},
#    '1': {'precision': 0.735593220338983,
#     'recall': 0.5081967213114754,
#     'f1-score': 0.6011080332409973,
#     'support': 427.0},
#    'accuracy': 0.712,
#    'macro avg': {'precision': 0.7188604399567255,
#     'recall': 0.6860355334306067,
#     'f1-score': 0.6878779602824705,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7164174540209161,
#     'recall': 0.712,
#     'f1-score': 0.7005463696305255,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 200), ('max_depth', 7))): {'params': {'n_estimators': 200,
#    'max_depth': 7},
#   'training_time': 33.15008187294006,
#   'classification_report': {'0': {'precision': 0.7095375722543352,
#     'recall': 0.8568935427574171,
#     'f1-score': 0.7762845849802371,
#     'support': 573.0},
#    '1': {'precision': 0.7337662337662337,
#     'recall': 0.5292740046838408,
#     'f1-score': 0.6149659863945578,
#     'support': 427.0},
#    'accuracy': 0.717,
#    'macro avg': {'precision': 0.7216519030102845,
#     'recall': 0.693083773720629,
#     'f1-score': 0.6956252856873975,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7198832107199159,
#     'recall': 0.717,
#     'f1-score': 0.7074015433841521,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'AdaBoost',
#   (('n_estimators',
#     50),)): {'params': {'n_estimators': 50}, 'training_time': 1.7479774951934814, 'classification_report': {'0': {'precision': 0.697274031563845,
#     'recall': 0.8481675392670157,
#     'f1-score': 0.7653543307086614,
#     'support': 573.0},
#    '1': {'precision': 0.7128712871287128,
#     'recall': 0.5058548009367682,
#     'f1-score': 0.5917808219178082,
#     'support': 427.0},
#    'accuracy': 0.702,
#    'macro avg': {'precision': 0.7050726593462789,
#     'recall': 0.6770111701018919,
#     'f1-score': 0.6785675763132348,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7039340596900435,
#     'recall': 0.702,
#     'f1-score': 0.691238442454967,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'AdaBoost',
#   (('n_estimators',
#     100),)): {'params': {'n_estimators': 100}, 'training_time': 2.8582088947296143, 'classification_report': {'0': {'precision': 0.7187017001545595,
#     'recall': 0.8115183246073299,
#     'f1-score': 0.7622950819672131,
#     'support': 573.0},
#    '1': {'precision': 0.6940509915014165,
#     'recall': 0.5737704918032787,
#     'f1-score': 0.6282051282051282,
#     'support': 427.0},
#    'accuracy': 0.71,
#    'macro avg': {'precision': 0.7063763458279879,
#     'recall': 0.6926444082053043,
#     'f1-score': 0.6952501050861706,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7081758475596674,
#     'recall': 0.71,
#     'f1-score': 0.7050386717108029,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'AdaBoost',
#   (('n_estimators',
#     150),)): {'params': {'n_estimators': 150}, 'training_time': 4.271351099014282, 'classification_report': {'0': {'precision': 0.7193798449612403,
#     'recall': 0.8097731239092496,
#     'f1-score': 0.7619047619047619,
#     'support': 573.0},
#    '1': {'precision': 0.6929577464788732,
#     'recall': 0.5761124121779859,
#     'f1-score': 0.629156010230179,
#     'support': 427.0},
#    'accuracy': 0.71,
#    'macro avg': {'precision': 0.7061687957200568,
#     'recall': 0.6929427680436178,
#     'f1-score': 0.6955303860674704,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7080976089092696,
#     'recall': 0.71,
#     'f1-score': 0.705221044939715,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'SGD',
#   (('alpha',
#     0.0001),)): {'params': {'alpha': 0.0001}, 'training_time': 0.17654061317443848, 'classification_report': {'0': {'precision': 0.729818780889621,
#     'recall': 0.7731239092495636,
#     'f1-score': 0.7508474576271187,
#     'support': 573.0},
#    '1': {'precision': 0.6692111959287532,
#     'recall': 0.6159250585480094,
#     'f1-score': 0.6414634146341464,
#     'support': 427.0},
#    'accuracy': 0.706,
#    'macro avg': {'precision': 0.6995149884091871,
#     'recall': 0.6945244838987865,
#     'f1-score': 0.6961554361306326,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7039393421113305,
#     'recall': 0.706,
#     'f1-score': 0.7041404712691195,
#     'support': 1000.0}}},
#  (418380670049,
#   TfidfVectorizer(),
#   'SGD',
#   (('alpha',
#     0.001),)): {'params': {'alpha': 0.001}, 'training_time': 0.15640568733215332, 'classification_report': {'0': {'precision': 0.6654088050314465,
#     'recall': 0.9232111692844677,
#     'f1-score': 0.7733918128654971,
#     'support': 573.0},
#    '1': {'precision': 0.7853658536585366,
#     'recall': 0.3770491803278688,
#     'f1-score': 0.509493670886076,
#     'support': 427.0},
#    'accuracy': 0.69,
#    'macro avg': {'precision': 0.7253873293449915,
#     'recall': 0.6501301748061683,
#     'f1-score': 0.6414427418757865,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7166304647952141,
#     'recall': 0.69,
#     'f1-score': 0.6607073062402842,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 100),
#    ('max_depth', None))): {'params': {'n_estimators': 100, 'max_depth': None},
#   'training_time': 18.72861671447754,
#   'classification_report': {'0': {'precision': 0.7633851468048359,
#     'recall': 0.7713787085514834,
#     'f1-score': 0.7673611111111112,
#     'support': 573.0},
#    '1': {'precision': 0.6888361045130641,
#     'recall': 0.6791569086651054,
#     'f1-score': 0.6839622641509434,
#     'support': 427.0},
#    'accuracy': 0.732,
#    'macro avg': {'precision': 0.72611062565895,
#     'recall': 0.7252678086082944,
#     'f1-score': 0.7256616876310273,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7315527057462493,
#     'recall': 0.732,
#     'f1-score': 0.7317498034591194,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 100), ('max_depth', 10))): {'params': {'n_estimators': 100,
#    'max_depth': 10},
#   'training_time': 0.5713338851928711,
#   'classification_report': {'0': {'precision': 0.5964172813487882,
#     'recall': 0.987783595113438,
#     'f1-score': 0.7437582128777924,
#     'support': 573.0},
#    '1': {'precision': 0.8627450980392157,
#     'recall': 0.10304449648711944,
#     'f1-score': 0.18410041841004185,
#     'support': 427.0},
#    'accuracy': 0.61,
#    'macro avg': {'precision': 0.729581189694002,
#     'recall': 0.5454140458002787,
#     'f1-score': 0.46392931564391715,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7101392590756008,
#     'recall': 0.61,
#     'f1-score': 0.504784334640063,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 100), ('max_depth', 20))): {'params': {'n_estimators': 100,
#    'max_depth': 20},
#   'training_time': 1.2483413219451904,
#   'classification_report': {'0': {'precision': 0.6383720930232558,
#     'recall': 0.9581151832460733,
#     'f1-score': 0.7662247034193999,
#     'support': 573.0},
#    '1': {'precision': 0.8285714285714286,
#     'recall': 0.2716627634660422,
#     'f1-score': 0.4091710758377425,
#     'support': 427.0},
#    'accuracy': 0.665,
#    'macro avg': {'precision': 0.7334717607973422,
#     'recall': 0.6148889733560577,
#     'f1-score': 0.5876978896285712,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7195872093023257,
#     'recall': 0.665,
#     'f1-score': 0.6137628044420321,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 150),
#    ('max_depth', None))): {'params': {'n_estimators': 150, 'max_depth': None},
#   'training_time': 27.840571641921997,
#   'classification_report': {'0': {'precision': 0.7588532883642496,
#     'recall': 0.7853403141361257,
#     'f1-score': 0.7718696397941681,
#     'support': 573.0},
#    '1': {'precision': 0.6977886977886978,
#     'recall': 0.6651053864168618,
#     'f1-score': 0.6810551558752997,
#     'support': 427.0},
#    'accuracy': 0.734,
#    'macro avg': {'precision': 0.7283209930764737,
#     'recall': 0.7252228502764937,
#     'f1-score': 0.726462397834734,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.732778708188489,
#     'recall': 0.734,
#     'f1-score': 0.7330918551608113,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 150), ('max_depth', 10))): {'params': {'n_estimators': 150,
#    'max_depth': 10},
#   'training_time': 0.8336763381958008,
#   'classification_report': {'0': {'precision': 0.5995762711864406,
#     'recall': 0.987783595113438,
#     'f1-score': 0.7462096242584048,
#     'support': 573.0},
#    '1': {'precision': 0.875,
#     'recall': 0.11475409836065574,
#     'f1-score': 0.2028985507246377,
#     'support': 427.0},
#    'accuracy': 0.615,
#    'macro avg': {'precision': 0.7372881355932204,
#     'recall': 0.5512688467370469,
#     'f1-score': 0.4745540874915212,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7171822033898304,
#     'recall': 0.615,
#     'f1-score': 0.5142157958594862,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 150), ('max_depth', 20))): {'params': {'n_estimators': 150,
#    'max_depth': 20},
#   'training_time': 1.8757970333099365,
#   'classification_report': {'0': {'precision': 0.641860465116279,
#     'recall': 0.9633507853403142,
#     'f1-score': 0.7704117236566643,
#     'support': 573.0},
#    '1': {'precision': 0.85,
#     'recall': 0.2786885245901639,
#     'f1-score': 0.41975308641975306,
#     'support': 427.0},
#    'accuracy': 0.671,
#    'macro avg': {'precision': 0.7459302325581395,
#     'recall': 0.621019654965239,
#     'f1-score': 0.5950824050382086,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7307360465116278,
#     'recall': 0.671,
#     'f1-score': 0.6206804855565032,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 200),
#    ('max_depth', None))): {'params': {'n_estimators': 200, 'max_depth': None},
#   'training_time': 37.30528163909912,
#   'classification_report': {'0': {'precision': 0.7524916943521595,
#     'recall': 0.7905759162303665,
#     'f1-score': 0.7710638297872341,
#     'support': 573.0},
#    '1': {'precision': 0.6984924623115578,
#     'recall': 0.6510538641686182,
#     'f1-score': 0.673939393939394,
#     'support': 427.0},
#    'accuracy': 0.731,
#    'macro avg': {'precision': 0.7254920783318586,
#     'recall': 0.7208148901994924,
#     'f1-score': 0.7225016118633141,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7294340222708227,
#     'recall': 0.731,
#     'f1-score': 0.7295916956802064,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 200), ('max_depth', 10))): {'params': {'n_estimators': 200,
#    'max_depth': 10},
#   'training_time': 1.1363434791564941,
#   'classification_report': {'0': {'precision': 0.600635593220339,
#     'recall': 0.9895287958115183,
#     'f1-score': 0.7475280158206987,
#     'support': 573.0},
#    '1': {'precision': 0.8928571428571429,
#     'recall': 0.117096018735363,
#     'f1-score': 0.2070393374741201,
#     'support': 427.0},
#    'accuracy': 0.617,
#    'macro avg': {'precision': 0.746746368038741,
#     'recall': 0.5533124072734407,
#     'f1-score': 0.4772836766474094,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7254141949152543,
#     'recall': 0.617,
#     'f1-score': 0.5167393501667097,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'RandomForest',
#   (('n_estimators', 200), ('max_depth', 20))): {'params': {'n_estimators': 200,
#    'max_depth': 20},
#   'training_time': 2.408437967300415,
#   'classification_report': {'0': {'precision': 0.6504739336492891,
#     'recall': 0.9581151832460733,
#     'f1-score': 0.7748764996471419,
#     'support': 573.0},
#    '1': {'precision': 0.8461538461538461,
#     'recall': 0.3091334894613583,
#     'f1-score': 0.4528301886792453,
#     'support': 427.0},
#    'accuracy': 0.681,
#    'macro avg': {'precision': 0.7483138899015676,
#     'recall': 0.6336243363537157,
#     'f1-score': 0.6138533441631936,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.734029256288735,
#     'recall': 0.681,
#     'f1-score': 0.63736272486385,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'SVC',
#   (('C', 1), ('kernel', 'linear'))): {'params': {'C': 1,
#    'kernel': 'linear'}, 'training_time': 12.747773885726929, 'classification_report': {'0': {'precision': 0.7290552584670231,
#     'recall': 0.7137870855148342,
#     'f1-score': 0.7213403880070547,
#     'support': 573.0},
#    '1': {'precision': 0.6264236902050114,
#     'recall': 0.6440281030444965,
#     'f1-score': 0.6351039260969977,
#     'support': 427.0},
#    'accuracy': 0.684,
#    'macro avg': {'precision': 0.6777394743360172,
#     'recall': 0.6789075942796654,
#     'f1-score': 0.6782221570520262,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6852315788191441,
#     'recall': 0.684,
#     'f1-score': 0.6845174187714603,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'SVC',
#   (('C', 1), ('kernel', 'rbf'))): {'params': {'C': 1,
#    'kernel': 'rbf'}, 'training_time': 12.419787883758545, 'classification_report': {'0': {'precision': 0.7144927536231884,
#     'recall': 0.8603839441535777,
#     'f1-score': 0.7806809184481394,
#     'support': 573.0},
#    '1': {'precision': 0.7419354838709677,
#     'recall': 0.5386416861826698,
#     'f1-score': 0.6241519674355496,
#     'support': 427.0},
#    'accuracy': 0.723,
#    'macro avg': {'precision': 0.7282141187470781,
#     'recall': 0.6995128151681238,
#     'f1-score': 0.7024164429418445,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7262107994389901,
#     'recall': 0.723,
#     'f1-score': 0.7138430563657635,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'SVC',
#   (('C', 10), ('kernel', 'linear'))): {'params': {'C': 10,
#    'kernel': 'linear'}, 'training_time': 17.10861587524414, 'classification_report': {'0': {'precision': 0.6902985074626866,
#     'recall': 0.6457242582897034,
#     'f1-score': 0.6672678088367899,
#     'support': 573.0},
#    '1': {'precision': 0.5625,
#     'recall': 0.6112412177985949,
#     'f1-score': 0.5858585858585859,
#     'support': 427.0},
#    'accuracy': 0.631,
#    'macro avg': {'precision': 0.6263992537313433,
#     'recall': 0.6284827380441491,
#     'f1-score': 0.626563197347688,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6357285447761194,
#     'recall': 0.631,
#     'f1-score': 0.6325060706250968,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'SVC',
#   (('C', 10), ('kernel', 'rbf'))): {'params': {'C': 10,
#    'kernel': 'rbf'}, 'training_time': 26.335997104644775, 'classification_report': {'0': {'precision': 0.7106518282988871,
#     'recall': 0.7801047120418848,
#     'f1-score': 0.7437603993344426,
#     'support': 573.0},
#    '1': {'precision': 0.660377358490566,
#     'recall': 0.5737704918032787,
#     'f1-score': 0.6140350877192983,
#     'support': 427.0},
#    'accuracy': 0.692,
#    'macro avg': {'precision': 0.6855145933947265,
#     'recall': 0.6769376019225817,
#     'f1-score': 0.6788977435268704,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.689184629690734,
#     'recall': 0.692,
#     'f1-score': 0.688367691274776,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'MultinomialNB',
#   (('alpha',
#     0.01),)): {'params': {'alpha': 0.01}, 'training_time': 0.13692736625671387, 'classification_report': {'0': {'precision': 0.7622080679405521,
#     'recall': 0.6265270506108203,
#     'f1-score': 0.6877394636015326,
#     'support': 573.0},
#    '1': {'precision': 0.5954631379962193,
#     'recall': 0.7377049180327869,
#     'f1-score': 0.6589958158995816,
#     'support': 427.0},
#    'accuracy': 0.674,
#    'macro avg': {'precision': 0.6788356029683857,
#     'recall': 0.6821159843218036,
#     'f1-score': 0.673367639750557,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.691007982854322,
#     'recall': 0.674,
#     'f1-score': 0.6754659260327995,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'MultinomialNB',
#   (('alpha',
#     1.0),)): {'params': {'alpha': 1.0}, 'training_time': 0.1509552001953125, 'classification_report': {'0': {'precision': 0.7791164658634538,
#     'recall': 0.6771378708551483,
#     'f1-score': 0.7245564892623716,
#     'support': 573.0},
#    '1': {'precision': 0.6314741035856574,
#     'recall': 0.7423887587822015,
#     'f1-score': 0.682454251883746,
#     'support': 427.0},
#    'accuracy': 0.705,
#    'macro avg': {'precision': 0.7052952847245556,
#     'recall': 0.7097633148186748,
#     'f1-score': 0.7035053705730587,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7160731771708347,
#     'recall': 0.705,
#     'f1-score': 0.7065788339016984,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'LogisticRegression',
#   (('C',
#     1),)): {'params': {'C': 1}, 'training_time': 0.4300844669342041, 'classification_report': {'0': {'precision': 0.7216828478964401,
#     'recall': 0.7783595113438045,
#     'f1-score': 0.7489504617968094,
#     'support': 573.0},
#    '1': {'precision': 0.6675392670157068,
#     'recall': 0.5971896955503513,
#     'f1-score': 0.630407911001236,
#     'support': 427.0},
#    'accuracy': 0.701,
#    'macro avg': {'precision': 0.6946110574560734,
#     'recall': 0.687774603447078,
#     'f1-score': 0.6896791863990227,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6985635388603669,
#     'recall': 0.701,
#     'f1-score': 0.6983327926070996,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'LogisticRegression',
#   (('C',
#     10),)): {'params': {'C': 10}, 'training_time': 0.6332852840423584, 'classification_report': {'0': {'precision': 0.727112676056338,
#     'recall': 0.7207678883071553,
#     'f1-score': 0.7239263803680982,
#     'support': 573.0},
#    '1': {'precision': 0.6296296296296297,
#     'recall': 0.6370023419203747,
#     'f1-score': 0.6332945285215367,
#     'support': 427.0},
#    'accuracy': 0.685,
#    'macro avg': {'precision': 0.6783711528429839,
#     'recall': 0.678885115113765,
#     'f1-score': 0.6786104544448175,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6854874152321335,
#     'recall': 0.685,
#     'f1-score': 0.6852265796296165,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     3),)): {'params': {'n_neighbors': 3}, 'training_time': 0.10548520088195801, 'classification_report': {'0': {'precision': 0.6391752577319587,
#     'recall': 0.8656195462478184,
#     'f1-score': 0.7353595255744997,
#     'support': 573.0},
#    '1': {'precision': 0.65625,
#     'recall': 0.3442622950819672,
#     'f1-score': 0.45161290322580644,
#     'support': 427.0},
#    'accuracy': 0.643,
#    'macro avg': {'precision': 0.6477126288659794,
#     'recall': 0.6049409206648928,
#     'f1-score': 0.593486214400153,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6464661726804123,
#     'recall': 0.643,
#     'f1-score': 0.6141997178316076,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     5),)): {'params': {'n_neighbors': 5}, 'training_time': 0.12445878982543945, 'classification_report': {'0': {'precision': 0.6285018270401949,
#     'recall': 0.900523560209424,
#     'f1-score': 0.7403156384505022,
#     'support': 573.0},
#    '1': {'precision': 0.6815642458100558,
#     'recall': 0.2857142857142857,
#     'f1-score': 0.40264026402640263,
#     'support': 427.0},
#    'accuracy': 0.638,
#    'macro avg': {'precision': 0.6550330364251253,
#     'recall': 0.5931189229618549,
#     'f1-score': 0.5714779512384525,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6511594798549255,
#     'recall': 0.638,
#     'f1-score': 0.5961282535714117,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     7),)): {'params': {'n_neighbors': 7}, 'training_time': 0.10363554954528809, 'classification_report': {'0': {'precision': 0.6152019002375297,
#     'recall': 0.9040139616055847,
#     'f1-score': 0.7321554770318022,
#     'support': 573.0},
#    '1': {'precision': 0.6518987341772152,
#     'recall': 0.24121779859484777,
#     'f1-score': 0.35213675213675216,
#     'support': 427.0},
#    'accuracy': 0.621,
#    'macro avg': {'precision': 0.6335503172073724,
#     'recall': 0.5726158801002162,
#     'f1-score': 0.5421461145842772,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6308714483297754,
#     'recall': 0.621,
#     'f1-score': 0.5698874815016158,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'DecisionTree',
#   (('max_depth',
#     None),)): {'params': {'max_depth': None}, 'training_time': 2.0335609912872314, 'classification_report': {'0': {'precision': 0.7527272727272727,
#     'recall': 0.7225130890052356,
#     'f1-score': 0.7373107747105966,
#     'support': 573.0},
#    '1': {'precision': 0.6466666666666666,
#     'recall': 0.6814988290398126,
#     'f1-score': 0.6636259977194983,
#     'support': 427.0},
#    'accuracy': 0.705,
#    'macro avg': {'precision': 0.6996969696969697,
#     'recall': 0.702005959022524,
#     'f1-score': 0.7004683862150474,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.707439393939394,
#     'recall': 0.705,
#     'f1-score': 0.7058473749353976,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'DecisionTree',
#   (('max_depth',
#     10),)): {'params': {'max_depth': 10}, 'training_time': 0.28511667251586914, 'classification_report': {'0': {'precision': 0.6666666666666666,
#     'recall': 0.8656195462478184,
#     'f1-score': 0.7532270311313591,
#     'support': 573.0},
#    '1': {'precision': 0.69921875,
#     'recall': 0.41920374707259955,
#     'f1-score': 0.5241581259150805,
#     'support': 427.0},
#    'accuracy': 0.675,
#    'macro avg': {'precision': 0.6829427083333333,
#     'recall': 0.642411646660209,
#     'f1-score': 0.6386925785232198,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.68056640625,
#     'recall': 0.675,
#     'f1-score': 0.6554146086040082,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'DecisionTree',
#   (('max_depth',
#     20),)): {'params': {'max_depth': 20}, 'training_time': 0.5083732604980469, 'classification_report': {'0': {'precision': 0.7274119448698315,
#     'recall': 0.8289703315881326,
#     'f1-score': 0.7748776508972267,
#     'support': 573.0},
#    '1': {'precision': 0.7175792507204611,
#     'recall': 0.5831381733021077,
#     'f1-score': 0.6434108527131783,
#     'support': 427.0},
#    'accuracy': 0.724,
#    'macro avg': {'precision': 0.7224955977951464,
#     'recall': 0.7060542524451201,
#     'f1-score': 0.7091442518052025,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7232133844680504,
#     'recall': 0.724,
#     'f1-score': 0.718741328072638,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 3))): {'params': {'n_estimators': 100,
#    'max_depth': 3},
#   'training_time': 3.9424548149108887,
#   'classification_report': {'0': {'precision': 0.6908850726552179,
#     'recall': 0.912739965095986,
#     'f1-score': 0.7864661654135339,
#     'support': 573.0},
#    '1': {'precision': 0.7942386831275721,
#     'recall': 0.4519906323185012,
#     'f1-score': 0.5761194029850746,
#     'support': 427.0},
#    'accuracy': 0.716,
#    'macro avg': {'precision': 0.7425618778913949,
#     'recall': 0.6823652987072436,
#     'f1-score': 0.6812927841993042,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7350170643269132,
#     'recall': 0.716,
#     'f1-score': 0.6966480978565817,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 5))): {'params': {'n_estimators': 100,
#    'max_depth': 5},
#   'training_time': 6.290070533752441,
#   'classification_report': {'0': {'precision': 0.6951724137931035,
#     'recall': 0.8795811518324608,
#     'f1-score': 0.7765793528505393,
#     'support': 573.0},
#    '1': {'precision': 0.7490909090909091,
#     'recall': 0.48243559718969553,
#     'f1-score': 0.5868945868945868,
#     'support': 427.0},
#    'accuracy': 0.71,
#    'macro avg': {'precision': 0.7221316614420064,
#     'recall': 0.6810083745110782,
#     'f1-score': 0.681736969872563,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7181956112852665,
#     'recall': 0.71,
#     'f1-score': 0.6955839577873476,
#     'support': 1000.0}}},
#  (418380670049,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 7))): {'params': {'n_estimators': 100,
#    'max_depth': 7},
#   'training_time': 10.00692868232727,
#   'classification_report': {'0': {'precision': 0.6951048951048951,
#     'recall': 0.8673647469458988,
#     'f1-score': 0.7717391304347826,
#     'support': 573.0},
#    '1': {'precision': 0.7333333333333333,
#     'recall': 0.4894613583138173,
#     'f1-score': 0.5870786516853933,
# ...
#     'recall': 0.7207678883071553,
#     'f1-score': 0.7239263803680982,
#     'support': 573.0},
#    '1': {'precision': 0.6296296296296297,
#     'recall': 0.6370023419203747,
#     'f1-score': 0.6332945285215367,
#     'support': 427.0},
#    'accuracy': 0.685,
#    'macro avg': {'precision': 0.6783711528429839,
#     'recall': 0.678885115113765,
#     'f1-score': 0.6786104544448175,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6854874152321335,
#     'recall': 0.685,
#     'f1-score': 0.6852265796296165,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     3),)): {'params': {'n_neighbors': 3}, 'training_time': 0.1102607250213623, 'classification_report': {'0': {'precision': 0.6391752577319587,
#     'recall': 0.8656195462478184,
#     'f1-score': 0.7353595255744997,
#     'support': 573.0},
#    '1': {'precision': 0.65625,
#     'recall': 0.3442622950819672,
#     'f1-score': 0.45161290322580644,
#     'support': 427.0},
#    'accuracy': 0.643,
#    'macro avg': {'precision': 0.6477126288659794,
#     'recall': 0.6049409206648928,
#     'f1-score': 0.593486214400153,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6464661726804123,
#     'recall': 0.643,
#     'f1-score': 0.6141997178316076,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     5),)): {'params': {'n_neighbors': 5}, 'training_time': 0.13296890258789062, 'classification_report': {'0': {'precision': 0.6285018270401949,
#     'recall': 0.900523560209424,
#     'f1-score': 0.7403156384505022,
#     'support': 573.0},
#    '1': {'precision': 0.6815642458100558,
#     'recall': 0.2857142857142857,
#     'f1-score': 0.40264026402640263,
#     'support': 427.0},
#    'accuracy': 0.638,
#    'macro avg': {'precision': 0.6550330364251253,
#     'recall': 0.5931189229618549,
#     'f1-score': 0.5714779512384525,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6511594798549255,
#     'recall': 0.638,
#     'f1-score': 0.5961282535714117,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'KNeighbors',
#   (('n_neighbors',
#     7),)): {'params': {'n_neighbors': 7}, 'training_time': 0.15309619903564453, 'classification_report': {'0': {'precision': 0.6152019002375297,
#     'recall': 0.9040139616055847,
#     'f1-score': 0.7321554770318022,
#     'support': 573.0},
#    '1': {'precision': 0.6518987341772152,
#     'recall': 0.24121779859484777,
#     'f1-score': 0.35213675213675216,
#     'support': 427.0},
#    'accuracy': 0.621,
#    'macro avg': {'precision': 0.6335503172073724,
#     'recall': 0.5726158801002162,
#     'f1-score': 0.5421461145842772,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6308714483297754,
#     'recall': 0.621,
#     'f1-score': 0.5698874815016158,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'DecisionTree',
#   (('max_depth', None),)): {'params': {'max_depth': None},
#   'training_time': 2.2777867317199707,
#   'classification_report': {'0': {'precision': 0.7356902356902357,
#     'recall': 0.7626527050610821,
#     'f1-score': 0.7489288774635818,
#     'support': 573.0},
#    '1': {'precision': 0.6650246305418719,
#     'recall': 0.6323185011709602,
#     'f1-score': 0.6482593037214885,
#     'support': 427.0},
#    'accuracy': 0.707,
#    'macro avg': {'precision': 0.7003574331160538,
#     'recall': 0.6974856031160211,
#     'f1-score': 0.6985940905925352,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7055160222918844,
#     'recall': 0.707,
#     'f1-score': 0.705942969475708,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'DecisionTree',
#   (('max_depth', 10),)): {'params': {'max_depth': 10},
#   'training_time': 0.3465442657470703,
#   'classification_report': {'0': {'precision': 0.668010752688172,
#     'recall': 0.8673647469458988,
#     'f1-score': 0.7547456340167046,
#     'support': 573.0},
#    '1': {'precision': 0.703125,
#     'recall': 0.4215456674473068,
#     'f1-score': 0.527086383601757,
#     'support': 427.0},
#    'accuracy': 0.677,
#    'macro avg': {'precision': 0.685567876344086,
#     'recall': 0.6444552071966028,
#     'f1-score': 0.6409160088092307,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6830045362903225,
#     'recall': 0.677,
#     'f1-score': 0.657535134089522,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'DecisionTree',
#   (('max_depth', 20),)): {'params': {'max_depth': 20},
#   'training_time': 0.6479809284210205,
#   'classification_report': {'0': {'precision': 0.72782874617737,
#     'recall': 0.8307155322862129,
#     'f1-score': 0.7758761206193969,
#     'support': 573.0},
#    '1': {'precision': 0.7196531791907514,
#     'recall': 0.5831381733021077,
#     'f1-score': 0.6442432082794308,
#     'support': 427.0},
#    'accuracy': 0.725,
#    'macro avg': {'precision': 0.7237409626840607,
#     'recall': 0.7069268527941603,
#     'f1-score': 0.7100596644494139,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.724337779074084,
#     'recall': 0.725,
#     'f1-score': 0.7196688670502315,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 3))): {'params': {'n_estimators': 100,
#    'max_depth': 3},
#   'training_time': 3.928471088409424,
#   'classification_report': {'0': {'precision': 0.6904761904761905,
#     'recall': 0.9109947643979057,
#     'f1-score': 0.7855530474040632,
#     'support': 573.0},
#    '1': {'precision': 0.7909836065573771,
#     'recall': 0.4519906323185012,
#     'f1-score': 0.5752608047690015,
#     'support': 427.0},
#    'accuracy': 0.715,
#    'macro avg': {'precision': 0.7407298985167838,
#     'recall': 0.6814926983582035,
#     'f1-score': 0.6804069260865324,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7333928571428571,
#     'recall': 0.715,
#     'f1-score': 0.6957582597988918,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 5))): {'params': {'n_estimators': 100,
#    'max_depth': 5},
#   'training_time': 7.393103122711182,
#   'classification_report': {'0': {'precision': 0.6936813186813187,
#     'recall': 0.881326352530541,
#     'f1-score': 0.776325903151422,
#     'support': 573.0},
#    '1': {'precision': 0.75,
#     'recall': 0.477751756440281,
#     'f1-score': 0.5836909871244635,
#     'support': 427.0},
#    'accuracy': 0.709,
#    'macro avg': {'precision': 0.7218406593406593,
#     'recall': 0.679539054485411,
#     'f1-score': 0.6800084451379428,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7177293956043956,
#     'recall': 0.709,
#     'f1-score': 0.6940707940079107,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 100), ('max_depth', 7))): {'params': {'n_estimators': 100,
#    'max_depth': 7},
#   'training_time': 10.746104955673218,
#   'classification_report': {'0': {'precision': 0.699859747545582,
#     'recall': 0.8708551483420593,
#     'f1-score': 0.776049766718507,
#     'support': 573.0},
#    '1': {'precision': 0.7421602787456446,
#     'recall': 0.49882903981264637,
#     'f1-score': 0.5966386554621849,
#     'support': 427.0},
#    'accuracy': 0.712,
#    'macro avg': {'precision': 0.7210100131456133,
#     'recall': 0.6848420940773529,
#     'f1-score': 0.6863442110903459,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7179220743680087,
#     'recall': 0.712,
#     'f1-score': 0.6994412222120575,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 150), ('max_depth', 3))): {'params': {'n_estimators': 150,
#    'max_depth': 3},
#   'training_time': 5.954894065856934,
#   'classification_report': {'0': {'precision': 0.6937669376693767,
#     'recall': 0.893542757417103,
#     'f1-score': 0.7810831426392068,
#     'support': 573.0},
#    '1': {'precision': 0.767175572519084,
#     'recall': 0.4707259953161593,
#     'f1-score': 0.5834542815674891,
#     'support': 427.0},
#    'accuracy': 0.713,
#    'macro avg': {'precision': 0.7304712550942303,
#     'recall': 0.6821343763666311,
#     'f1-score': 0.6822687121033479,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7251124247502017,
#     'recall': 0.713,
#     'f1-score': 0.6966956189615834,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 150), ('max_depth', 5))): {'params': {'n_estimators': 150,
#    'max_depth': 5},
#   'training_time': 10.63064956665039,
#   'classification_report': {'0': {'precision': 0.6984785615491009,
#     'recall': 0.881326352530541,
#     'f1-score': 0.779320987654321,
#     'support': 573.0},
#    '1': {'precision': 0.7545126353790613,
#     'recall': 0.4894613583138173,
#     'f1-score': 0.59375,
#     'support': 427.0},
#    'accuracy': 0.714,
#    'macro avg': {'precision': 0.7264955984640811,
#     'recall': 0.6853938554221792,
#     'f1-score': 0.6865354938271605,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.722405111074494,
#     'recall': 0.714,
#     'f1-score': 0.7000821759259259,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 150), ('max_depth', 7))): {'params': {'n_estimators': 150,
#    'max_depth': 7},
#   'training_time': 15.103183507919312,
#   'classification_report': {'0': {'precision': 0.7026647966339411,
#     'recall': 0.8743455497382199,
#     'f1-score': 0.7791601866251944,
#     'support': 573.0},
#    '1': {'precision': 0.7491289198606271,
#     'recall': 0.5035128805620609,
#     'f1-score': 0.6022408963585434,
#     'support': 427.0},
#    'accuracy': 0.716,
#    'macro avg': {'precision': 0.7258968582472841,
#     'recall': 0.6889292151501404,
#     'f1-score': 0.6907005414918689,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7225049772517361,
#     'recall': 0.716,
#     'f1-score': 0.7036156496813344,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 200), ('max_depth', 3))): {'params': {'n_estimators': 200,
#    'max_depth': 3},
#   'training_time': 7.541140556335449,
#   'classification_report': {'0': {'precision': 0.6995884773662552,
#     'recall': 0.8900523560209425,
#     'f1-score': 0.783410138248848,
#     'support': 573.0},
#    '1': {'precision': 0.7675276752767528,
#     'recall': 0.48711943793911006,
#     'f1-score': 0.5959885386819485,
#     'support': 427.0},
#    'accuracy': 0.718,
#    'macro avg': {'precision': 0.7335580763215039,
#     'recall': 0.6885858969800263,
#     'f1-score': 0.6896993384653982,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7285985148740376,
#     'recall': 0.718,
#     'f1-score': 0.7033811152337819,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 200), ('max_depth', 5))): {'params': {'n_estimators': 200,
#    'max_depth': 5},
#   'training_time': 13.240647077560425,
#   'classification_report': {'0': {'precision': 0.7045454545454546,
#     'recall': 0.8656195462478184,
#     'f1-score': 0.7768206734534064,
#     'support': 573.0},
#    '1': {'precision': 0.7398648648648649,
#     'recall': 0.5128805620608899,
#     'f1-score': 0.6058091286307054,
#     'support': 427.0},
#    'accuracy': 0.715,
#    'macro avg': {'precision': 0.7222051597051597,
#     'recall': 0.6892500541543543,
#     'f1-score': 0.6913149010420558,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7196268427518427,
#     'recall': 0.715,
#     'f1-score': 0.7037987438141131,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'GradientBoosting',
#   (('n_estimators', 200), ('max_depth', 7))): {'params': {'n_estimators': 200,
#    'max_depth': 7},
#   'training_time': 18.477378606796265,
#   'classification_report': {'0': {'precision': 0.707492795389049,
#     'recall': 0.8568935427574171,
#     'f1-score': 0.7750591949486977,
#     'support': 573.0},
#    '1': {'precision': 0.7320261437908496,
#     'recall': 0.5245901639344263,
#     'f1-score': 0.6111869031377899,
#     'support': 427.0},
#    'accuracy': 0.715,
#    'macro avg': {'precision': 0.7197594695899493,
#     'recall': 0.6907418533459218,
#     'f1-score': 0.6931230490432438,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.717968535156618,
#     'recall': 0.715,
#     'f1-score': 0.7050857263454401,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'AdaBoost',
#   (('n_estimators',
#     50),)): {'params': {'n_estimators': 50}, 'training_time': 0.964245080947876, 'classification_report': {'0': {'precision': 0.7115942028985507,
#     'recall': 0.8568935427574171,
#     'f1-score': 0.777513855898654,
#     'support': 573.0},
#    '1': {'precision': 0.7354838709677419,
#     'recall': 0.5339578454332553,
#     'f1-score': 0.6187245590230664,
#     'support': 427.0},
#    'accuracy': 0.719,
#    'macro avg': {'precision': 0.7235390369331463,
#     'recall': 0.6954256940953363,
#     'f1-score': 0.6981192074608602,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7217950911640953,
#     'recall': 0.719,
#     'f1-score': 0.709710826132778,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'AdaBoost',
#   (('n_estimators', 100),)): {'params': {'n_estimators': 100},
#   'training_time': 1.8461363315582275,
#   'classification_report': {'0': {'precision': 0.7221374045801526,
#     'recall': 0.8254799301919721,
#     'f1-score': 0.7703583061889251,
#     'support': 573.0},
#    '1': {'precision': 0.7101449275362319,
#     'recall': 0.5737704918032787,
#     'f1-score': 0.6347150259067358,
#     'support': 427.0},
#    'accuracy': 0.718,
#    'macro avg': {'precision': 0.7161411660581922,
#     'recall': 0.6996252109976253,
#     'f1-score': 0.7025366660478305,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.7170166168823985,
#     'recall': 0.718,
#     'f1-score': 0.7124386255084303,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'AdaBoost',
#   (('n_estimators', 150),)): {'params': {'n_estimators': 150},
#   'training_time': 2.8862392902374268,
#   'classification_report': {'0': {'precision': 0.719626168224299,
#     'recall': 0.806282722513089,
#     'f1-score': 0.7604938271604939,
#     'support': 573.0},
#    '1': {'precision': 0.6899441340782123,
#     'recall': 0.5784543325526932,
#     'f1-score': 0.6292993630573248,
#     'support': 427.0},
#    'accuracy': 0.709,
#    'macro avg': {'precision': 0.7047851511512557,
#     'recall': 0.692368527532891,
#     'f1-score': 0.6948965951089093,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.70695193964392,
#     'recall': 0.709,
#     'f1-score': 0.7044737909884407,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'SGD',
#   (('alpha',
#     0.0001),)): {'params': {'alpha': 0.0001}, 'training_time': 0.20819878578186035, 'classification_report': {'0': {'precision': 0.7316636851520573,
#     'recall': 0.7137870855148342,
#     'f1-score': 0.7226148409893993,
#     'support': 573.0},
#    '1': {'precision': 0.6281179138321995,
#     'recall': 0.6487119437939111,
#     'f1-score': 0.6382488479262672,
#     'support': 427.0},
#    'accuracy': 0.686,
#    'macro avg': {'precision': 0.6798907994921284,
#     'recall': 0.6812495146543727,
#     'f1-score': 0.6804318444578332,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.6874496407984779,
#     'recall': 0.686,
#     'f1-score': 0.686590561951442,
#     'support': 1000.0}}},
#  (29114468376207731,
#   CountVectorizer(),
#   'SGD',
#   (('alpha',
#     0.001),)): {'params': {'alpha': 0.001}, 'training_time': 0.21209049224853516, 'classification_report': {'0': {'precision': 0.7257318952234206,
#     'recall': 0.8219895287958116,
#     'f1-score': 0.7708674304418985,
#     'support': 573.0},
#    '1': {'precision': 0.7094017094017094,
#     'recall': 0.5831381733021077,
#     'f1-score': 0.6401028277634961,
#     'support': 427.0},
#    'accuracy': 0.72,
#    'macro avg': {'precision': 0.717566802312565,
#     'recall': 0.7025638510489596,
#     'f1-score': 0.7054851291026973,
#     'support': 1000.0},
#    'weighted avg': {'precision': 0.71875890587755,
#     'recall': 0.72,
#     'f1-score': 0.7150309450982206,
#     'support': 1000.0}}}}

# %% [markdown]
# # Process results

# %%
results.items()
# Out:
# dict_items([((418380670049, TfidfVectorizer(), 'RandomForest', (('n_estimators', 100), ('max_depth', None))), {'params': {'n_estimators': 100, 'max_depth': None}, 'training_time': 17.593130826950073, 'classification_report': {'0': {'precision': 0.7185185185185186, 'recall': 0.8464223385689355, 'f1-score': 0.7772435897435898, 'support': 573.0}, '1': {'precision': 0.7292307692307692, 'recall': 0.5550351288056206, 'f1-score': 0.6303191489361702, 'support': 427.0}, 'accuracy': 0.722, 'macro avg': {'precision': 0.723874643874644, 'recall': 0.7007287336872781, 'f1-score': 0.70378136933988, 'support': 1000.0}, 'weighted avg': {'precision': 0.7230926495726496, 'recall': 0.722, 'f1-score': 0.7145068535188216, 'support': 1000.0}}}), ((418380670049, TfidfVectorizer(), 'RandomForest', (('n_estimators', 100), ('max_depth', 10))), {'params': {'n_estimators': 100, 'max_depth': 10}, 'training_time': 0.7226264476776123, 'classification_report': {'0': {'precision': 0.5916666666666667, 'recall': 0.9912739965095986, 'f1-score': 0.741030658838878, 'support': 573.0}, '1': {'precision': 0.875, 'recall': 0.08196721311475409, 'f1-score': 0.14989293361884368, 'support': 427.0}, 'accuracy': 0.603, 'macro avg': {'precision': 0.7333333333333334, 'recall': 0.5366206048121763, 'f1-score': 0.44546179622886084, 'support': 1000.0}, 'weighted avg': {'precision': 0.71265, 'recall': 0.603, 'f1-score': 0.48861485016992334, 'support': 1000.0}}}), ((418380670049, TfidfVectorizer(), 'RandomForest', (('n_estimators', 100), ('max_depth', 20))), {'params': {'n_estimators': 100, 'max_depth': 20}, 'training_time': 1.524521827697754, 'classification_report': {'0': {'precision': 0.6453900709219859, 'recall': 0.9528795811518325, 'f1-score': 0.7695560253699789, 'support': 573.0}, '1': {'precision': 0.8246753246753247, 'recall': 0.297423887587822, 'f1-score': 0.43717728055077454, 'support': 427.0}, 'accuracy': 0.673, 'macro avg': {'precision': 0.7350326977986552, 'recall': 0.6251517343698272, 'f1-score': 0.6033666529603767, 'support': 1000.0}, 'weighted avg': {'precision': 0.7219448742746615, 'recall': 0.673, 'f1-score': 0.6276303013321787, 'support': 1000.0}}})])

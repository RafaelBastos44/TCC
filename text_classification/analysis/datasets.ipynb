# %%
import pandas as pd
from datasets import load_dataset
from matplotlib import pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer

# %%
ds = load_dataset("christinacdl/binary_hate_speech")

# %%
train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

label_mapping = {'NOT_OFF_HATEFUL_TOXIC': 'Seguro', 'OFF_HATEFUL_TOXIC': 'Discurso de Ódio'}
train['label'] = train['label'].map(label_mapping)

print("Labels:")
print(train['label'].unique())

plt.figure(figsize=(10, 6))
train['label'].value_counts().plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 31060 samples
# Validation set: 3883 samples
# Test set: 3883 samples
# Labels:
# ['Seguro' 'Discurso de Ódio']

# %%
ds = load_dataset("cornell-movie-review-data/rotten_tomatoes")

# %%
train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

label_mapping = {0: 'Negativo', 1: 'Positivo'}
train['label'] = train['label'].map(label_mapping)

print("Labels:")
print(train['label'].unique())

plt.figure(figsize=(10, 6))
train['label'].value_counts().plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 8530 samples
# Validation set: 1066 samples
# Test set: 1066 samples
# Labels:
# ['Positivo' 'Negativo']

# %%
ds = load_dataset("cardiffnlp/tweet_eval", "irony")

# %%
train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

label_mapping = {0: 'Não ironico', 1: 'Ironico'}
train['label'] = train['label'].map(label_mapping)

print("Labels:")
print(train['label'].unique())

plt.figure(figsize=(10, 6))
train['label'].value_counts().plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 2862 samples
# Validation set: 955 samples
# Test set: 784 samples
# Labels:
# ['Ironico' 'Não ironico']

# %%
ds = load_dataset("cardiffnlp/tweet_eval", "sentiment")

# %%
train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

label_mapping = {0: 'Negativo', 1: 'Neutro', 2: 'Positivo'}
train['label'] = train['label'].map(label_mapping)

print("Labels:")
print(train['label'].unique())

plt.figure(figsize=(10, 6))
train['label'].value_counts().plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 45615 samples
# Validation set: 2000 samples
# Test set: 12284 samples
# Labels:
# ['Positivo' 'Neutro' 'Negativo']

# %%
ds = load_dataset("KushT/bbc_news_multiclass_train_val_test")

# %%
train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

label_mapping = {0: 'business', 1: 'entertainment', 2: 'politics', 3: 'sport', 4: 'tech'}
train['label'] = train['label'].map(label_mapping)

print("Labels:")
print(train['label'].unique())

plt.figure(figsize=(10, 6))
train['label'].value_counts().plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 1512 samples
# Validation set: 379 samples
# Test set: 334 samples
# Labels:
# ['business' 'politics' 'entertainment' 'sport' 'tech']

# %%
ds = load_dataset("dair-ai/emotion", "split")

# %%
train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

label_mapping = {0: 'sadness', 1: 'joy', 2: 'love', 3: 'anger', 4: 'fear', 5: 'surprise'}
train['label'] = train['label'].map(label_mapping)

print("Labels:")
print(train['label'].unique())

plt.figure(figsize=(10, 6))
train['label'].value_counts().plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 16000 samples
# Validation set: 2000 samples
# Test set: 2000 samples
# Labels:
# ['sadness' 'anger' 'love' 'surprise' 'fear' 'joy']

# %%
ds = load_dataset("higopires/RePro-categories-multilabel")

# %%
train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

class_counts = train.drop(columns=['review_text']).sum().sort_values(ascending=False)

print("Labels:")
print(class_counts.index.tolist())

plt.figure(figsize=(10, 6))
class_counts.plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 8002 samples
# Validation set: 994 samples
# Test set: 1007 samples
# Labels:
# ['PRODUTO', 'ENTREGA', 'OUTROS', 'CONDICOESDERECEBIMENTO', 'ANUNCIO', 'INADEQUADA']

# %%
ds = load_dataset("Rami/multi-label-class-github-issues-text-classification")

train = ds['train'].to_pandas()
val = ds['valid'].to_pandas()
test = ds['test'].to_pandas()

# %%
allowed_categories = ["bug", "feature", "question", "won't fix", "docs"]

def clean_element(lst):
    final = []
    for elem in lst:
        clean = elem.split('->')[-1]
        final.append(clean)
    return final

train['labels'] = train['labels'].apply(clean_element)
test['labels'] = test['labels'].apply(clean_element)
val['labels'] = val['labels'].apply(clean_element)

train = train[train['labels'].apply(lambda cats: all(c in allowed_categories for c in cats))]
test = test[test['labels'].apply(lambda cats: all(c in allowed_categories for c in cats))]
val = val[val['labels'].apply(lambda cats: all(c in allowed_categories for c in cats))]

train = train[train['labels'].apply(len) > 0]
test = test[test['labels'].apply(len) > 0]
val = val[val['labels'].apply(len) > 0]

train.rename(columns={'title': 'text'}, inplace=True)
test.rename(columns={'title': 'text'}, inplace=True)
val.rename(columns={'title': 'text'}, inplace=True)

train.drop(columns=['bodyText'], inplace=True)
test.drop(columns=['bodyText'], inplace=True)
val.drop(columns=['bodyText'], inplace=True)

train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)
val.reset_index(drop=True, inplace=True)

# %%
mlb = MultiLabelBinarizer()

train_labels_binarized = mlb.fit_transform(train['labels'])
val_labels_binarized = mlb.transform(val['labels'])
test_labels_binarized = mlb.transform(test['labels'])

train_labels_df = pd.DataFrame(train_labels_binarized, columns=mlb.classes_)
val_labels_df = pd.DataFrame(val_labels_binarized, columns=mlb.classes_)
test_labels_df = pd.DataFrame(test_labels_binarized, columns=mlb.classes_)

train = pd.concat([train, train_labels_df], axis=1)
val = pd.concat([val, val_labels_df], axis=1)
test = pd.concat([test, test_labels_df], axis=1)

train = train.drop(columns=['labels'])
val = val.drop(columns=['labels'])
test = test.drop(columns=['labels'])

train
# Out:
#                                                   text  bug  docs  feature  \
# 0                       Fix docs typo in starter files    0     1        0
# 1                            Fix typo in starter files    0     1        0
# 2     Load models give different results from original    0     0        0
# 3         Pickle error and OOM when upgrading to 1.2.0    0     0        0
# 4    val_check_interval equivalent for training los...    0     0        0
# ..                                                 ...  ...   ...      ...
# 410                     How to implement pre-training?    0     0        0
# 411                  Logging the current learning rate    0     0        0
# 412  Example of gradient accumulation documentation...    0     1        0
# 413  Checkpooint Callback not called when training ...    0     0        0
# 414  Evaluation on subsampled training set during t...    0     0        0
#
#      question  won't fix
# 0           0          0
# 1           0          0
# 2           1          0
# 3           1          1
# 4           0          1
# ..        ...        ...
# 410         1          0
# 411         1          0
# 412         0          0
# 413         1          0
# 414         1          0
#
# [415 rows x 6 columns]

# %%
print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

class_counts = train.drop(columns=['text']).sum().sort_values(ascending=False)

print("Labels:")
print(class_counts.index.tolist())

plt.figure(figsize=(10, 6))
class_counts.plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 415 samples
# Validation set: 187 samples
# Test set: 200 samples
# Labels:
# ['question', 'bug', "won't fix", 'docs', 'feature']

# %%
ds = load_dataset("TimSchopf/arxiv_categories", "default")

train = ds['train'].to_pandas()
test = ds['test'].to_pandas() 
val = ds['validation'].to_pandas()

# %%
allowed_categories = ["cs.AI", "cs.CL", "stat.ML", "math.OC", "cs.LG"]

def clean_element(lst):
    final = []
    for elem in lst:
        clean = elem.split('->')[-1]
        final.append(clean)
    return final

train['categories'] = train['categories'].apply(clean_element)
test['categories'] = test['categories'].apply(clean_element)
val['categories'] = val['categories'].apply(clean_element)

train = train[train['categories'].apply(lambda cats: all(c in allowed_categories for c in cats))]
test = test[test['categories'].apply(lambda cats: all(c in allowed_categories for c in cats))]
val = val[val['categories'].apply(lambda cats: all(c in allowed_categories for c in cats))]

train.rename(columns={'categories': 'labels'}, inplace=True)
test.rename(columns={'categories': 'labels'}, inplace=True)
val.rename(columns={'categories': 'labels'}, inplace=True)

train.rename(columns={'title': 'text'}, inplace=True)
test.rename(columns={'title': 'text'}, inplace=True)
val.rename(columns={'title': 'text'}, inplace=True)

train.drop(columns=['id', 'abstract', 'creation_date'], inplace=True)
test.drop(columns=['id', 'abstract', 'creation_date'], inplace=True)
val.drop(columns=['id', 'abstract', 'creation_date'], inplace=True)

train.reset_index(drop=True, inplace=True)
test.reset_index(drop=True, inplace=True)
val.reset_index(drop=True, inplace=True)

# %%
mlb = MultiLabelBinarizer()

train_labels_binarized = mlb.fit_transform(train['labels'])
val_labels_binarized = mlb.transform(val['labels'])
test_labels_binarized = mlb.transform(test['labels'])

train_labels_df = pd.DataFrame(train_labels_binarized, columns=mlb.classes_)
val_labels_df = pd.DataFrame(val_labels_binarized, columns=mlb.classes_)
test_labels_df = pd.DataFrame(test_labels_binarized, columns=mlb.classes_)

train = pd.concat([train, train_labels_df], axis=1)
val = pd.concat([val, val_labels_df], axis=1)
test = pd.concat([test, test_labels_df], axis=1)

train = train.drop(columns=['labels'])
val = val.drop(columns=['labels'])
test = test.drop(columns=['labels'])

train
# Out:
#                                                     text  cs.AI  cs.CL  cs.LG  \
# 0      Upper and Lower Bounds for Large Scale Multist...      0      0      0
# 1      Binary Classification: Counterbalancing Class ...      0      0      1
# 2          Smooth Optimization with Approximate Gradient      0      0      0
# 3      An AI-powered Smart Routing Solution for Payme...      1      0      0
# 4      A linearly convergent method for solving high-...      0      0      0
# ...                                                  ...    ...    ...    ...
# 10141  Simple Question Answering with Subgraph Rankin...      0      1      1
# 10142  Fire Now, Fire Later: Alarm-Based Systems for ...      1      0      1
# 10143  NSP-BERT: A Prompt-based Few-Shot Learner Thro...      1      1      0
# 10144      Near-optimal bounds for phase synchronization      0      0      0
# 10145  Rapid Convergence of First-Order Numerical Alg...      0      0      0
#
#        math.OC  stat.ML
# 0            1        0
# 1            0        0
# 2            1        0
# 3            0        0
# 4            1        0
# ...        ...      ...
# 10141        0        1
# 10142        0        1
# 10143        0        0
# 10144        1        0
# 10145        1        0
#
# [10146 rows x 6 columns]

# %%
print(f"Train set: {train.shape[0]} samples")
print(f"Validation set: {val.shape[0]} samples")
print(f"Test set: {test.shape[0]} samples")

class_counts = train.drop(columns=['text']).sum().sort_values(ascending=False)

print("Labels:")
print(class_counts.index.tolist())

plt.figure(figsize=(10, 6))
class_counts.plot(kind='bar')
plt.title('Distribuição de Classes no Conjunto de Treinamento')
plt.xlabel('Classes')
plt.ylabel('Número de Amostras')
plt.xticks(rotation=45)
plt.show()
# Out:
# Train set: 10146 samples
# Validation set: 1266 samples
# Test set: 1270 samples
# Labels:
# ['cs.LG', 'cs.CL', 'cs.AI', 'stat.ML', 'math.OC']

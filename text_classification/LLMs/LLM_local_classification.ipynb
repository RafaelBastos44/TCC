# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

# %%
import os
os.environ["HUGGINGFACE_TOKEN"] = "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"

# %%
model_name = "google/gemma-2-2b"
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=os.getenv("HUGGINGFACE_TOKEN"))
model = AutoModelForCausalLM.from_pretrained(model_name, use_auth_token=os.getenv("HUGGINGFACE_TOKEN"))

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Prepare input
input_text = "Once upon a time"
inputs = tokenizer(input_text, return_tensors="pt").to(device)

# Generate output
with torch.no_grad():
    outputs = model.generate(**inputs, max_length=50)

# Decode and print the output
generated_text = tokenizer.decode(outputs[0].cpu(), skip_special_tokens=True)
print(generated_text)
# Out:
# Loading checkpoint shards: 100%|██████████| 3/3 [00:00<00:00,  5.88it/s]
# Once upon a time, there was a little girl who was born with a heart condition. She was born with a hole in her heart, and she had to have surgery to fix it. The surgery was successful, and the little girl was able

# %%
# Prepare input
input_text = """ one plus one equals: """
inputs = tokenizer(input_text, return_tensors="pt").to(device)

print("1")
# Generate output
with torch.no_grad():
    outputs = model.generate(**inputs, max_length=400)
print("2")
# Decode and print the output
generated_text = tokenizer.decode(outputs[0].cpu(), skip_special_tokens=True)
print(generated_text)
# Out:
# 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 8
#       6 # Generate output
#       7 with torch.no_grad():
# ----> 8     outputs = model.generate(**inputs, max_length=400)
#       9 print("2")
#      10 # Decode and print the output
#
# File c:\Users\Rafael\Desktop\Prog\TCC\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# ...

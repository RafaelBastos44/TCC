# %%
import os
import time
from google import genai
from google.genai import types
from dotenv import load_dotenv
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, hamming_loss


from datasets import load_dataset

# %%
ds = load_dataset("TimSchopf/arxiv_categories", "default")

test = ds['test'].to_pandas()

test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20397 entries, 0 to 20396
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             20397 non-null  object
#  1   title          20397 non-null  object
#  2   abstract       20397 non-null  object
#  3   categories     20397 non-null  object
#  4   creation_date  20397 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), object(4)
# memory usage: 796.9+ KB

# %%
test = test.rename(columns={'title': 'text'})
test = test.rename(columns={'categories': 'labels'})

# %%
def clean_element(lst):
    final = []
    for elem in lst:
        clean = elem.split('->')[-1]
        final.append(clean)
    return final

test['labels'] = test['labels'].apply(clean_element)

test
# Out:
#                      id                                               text  \
# 0            2208.11718  gSwin: Gated MLP Vision Model with Hierarchica...
# 1            2302.13571  FLAG: Fast Label-Adaptive Aggregation for Mult...
# 2            2208.12842  Advances in device-independent quantum key dis...
# 3            2303.07834  Finite-Horizon Constrained MDPs With Both Addi...
# 4            1504.07490  Exact equations for structure functions and eq...
# ...                 ...                                                ...
# 20392        1608.05170  Resource efficient redundancy using quorum-bas...
# 20393  cond-mat/9504003  An almost sure large deviation principle for t...
# 20394         1412.5555  Local stability of Kolmogorov forward equation...
# 20395  astro-ph/0408428  An Analysis of the Large Scale N-body Simulati...
# 20396        1507.01747  Invisible decays of the heavier Higgs boson in...
#
#                                                 abstract              labels  \
# 0      Following the success in language domain, the ...      [cs.CV, cs.LG]
# 1      Federated learning aims to share private data ...      [cs.AI, cs.LG]
# 2      Device-independent quantum key distribution (D...          [quant-ph]
# 3      This paper considers the problem of finding a ...  [math.OC, math.PR]
# 4      We derive equations for the source terms appea...   [physics.flu-dyn]
# ...                                                  ...                 ...
# 20392  In this paper we propose a cycle redundancy te...             [cs.NI]
# 20393  We prove a large deviation principle for the f...          [cond-mat]
# 20394  The focus of this work is on local stability o...           [math.PR]
# 20395  We analyze the Minkowski functionals with a la...          [astro-ph]
# 20396  We consider the possibility that the heavier C...            [hep-ph]
#
#                   creation_date
# 0     2022-08-24 18:00:46+00:00
# 1     2023-02-27 08:16:39+00:00
# 2     2022-08-26 18:55:40+00:00
# 3     2023-03-14 12:15:58+00:00
# 4     2015-04-28 14:17:44+00:00
# ...                         ...
# 20392 2016-08-18 04:35:50+00:00
# 20393 1995-04-03 11:11:22+00:00
# 20394 2014-12-17 20:03:13+00:00
# 20395 2004-08-24 06:12:43+00:00
# 20396 2015-07-07 10:39:40+00:00
#
# [20397 rows x 5 columns]

# %%
labels = ["cs.AI", "cs.CL", "stat.ML", "math.OC", "cs.LG"]

test = test[test['labels'].apply(lambda cats: all(c in labels for c in cats))]
test = test[test['labels'].apply(len) > 0]
test.drop(columns=['id','abstract','creation_date'], inplace=True)
test.reset_index(drop=True, inplace=True)

test
# Out:
#                                                    text  \
# 0     FLAG: Fast Label-Adaptive Aggregation for Mult...
# 1       Large-Margin Classification in Hyperbolic Space
# 2     Student Specialization in Deep ReLU Networks W...
# 3     Joint Modelling of Emotion and Abusive Languag...
# 4     Allocation of Excitation Signals for Generic I...
# ...                                                 ...
# 1265  Benign Overfitting in Two-layer Convolutional ...
# 1266  An FPGA-Based On-Device Reinforcement Learning...
# 1267  Something for (almost) nothing: Improving deep...
# 1268  An Alternative to Variance: Gini Deviation for...
# 1269  Concept Learning through Deep Reinforcement Le...
#
#                          labels
# 0                [cs.AI, cs.LG]
# 1              [cs.LG, stat.ML]
# 2              [cs.LG, stat.ML]
# 3                [cs.CL, cs.LG]
# 4                     [math.OC]
# ...                         ...
# 1265  [cs.LG, math.OC, stat.ML]
# 1266           [cs.LG, stat.ML]
# 1267                    [cs.LG]
# 1268             [cs.AI, cs.LG]
# 1269             [cs.AI, cs.LG]
#
# [1270 rows x 2 columns]

# %%
mlb = MultiLabelBinarizer()
test_labels_binarized = mlb.fit_transform(test['labels'])

test_labels_df = pd.DataFrame(test_labels_binarized, columns=mlb.classes_)

test = pd.concat([test, test_labels_df], axis=1)

test.drop(columns=['labels'], inplace=True)

test
# Out:
#                                                    text  cs.AI  cs.CL  cs.LG  \
# 0     FLAG: Fast Label-Adaptive Aggregation for Mult...      1      0      1
# 1       Large-Margin Classification in Hyperbolic Space      0      0      1
# 2     Student Specialization in Deep ReLU Networks W...      0      0      1
# 3     Joint Modelling of Emotion and Abusive Languag...      0      1      1
# 4     Allocation of Excitation Signals for Generic I...      0      0      0
# ...                                                 ...    ...    ...    ...
# 1265  Benign Overfitting in Two-layer Convolutional ...      0      0      1
# 1266  An FPGA-Based On-Device Reinforcement Learning...      0      0      1
# 1267  Something for (almost) nothing: Improving deep...      0      0      1
# 1268  An Alternative to Variance: Gini Deviation for...      1      0      1
# 1269  Concept Learning through Deep Reinforcement Le...      1      0      1
#
#       math.OC  stat.ML
# 0           0        0
# 1           0        1
# 2           0        1
# 3           0        0
# 4           1        0
# ...       ...      ...
# 1265        1        1
# 1266        0        1
# 1267        0        0
# 1268        0        0
# 1269        0        0
#
# [1270 rows x 6 columns]

# %%
load_dotenv()

api_key=os.environ.get("GEMINI_API_KEY")
client = genai.Client(api_key=api_key)

# %%
def classify(text, labels):

    sys_instruct="You are a classification assistant. Your objective is to read the provided text and classify it according to the task and labels described. You are capable of handling multilabel classification tasks based on user instructions."

    start_time = time.time()

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        config=types.GenerateContentConfig(
            system_instruction=sys_instruct,
            safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_HARASSMENT",
                threshold="BLOCK_NONE"
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_HATE_SPEECH",
                threshold="BLOCK_NONE"
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_SEXUALLY_EXPLICIT",
                threshold="BLOCK_NONE"
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_NONE"
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_CIVIC_INTEGRITY",
                threshold="BLOCK_NONE"
            ),
            ],
        ),
        contents=f"Classify the following text based on the task: Classification of computer science-based arXiv articles. Only respond with the labels that best describe the text. The possible labels are: {', '.join(labels)}. Text: {text}"
    )

    request_time = time.time() - start_time
    completion = response.text
    if completion:
        completion = completion.lower()
    else:
        completion = "None"
    completion_tokens = response.usage_metadata.candidates_token_count
    prompt_tokens = response.usage_metadata.prompt_token_count
    total_tokens = response.usage_metadata.total_token_count

    return completion, request_time, completion_tokens, prompt_tokens, total_tokens

def post_process(text):
    list = []
    if 'artificial intelligence' in text:
        list.append('cs.AI')
    if 'computation and language' in text:
        list.append('cs.CL')
    if 'statistics machine learning' in text:
        list.append('stat.ML')
    if 'optimization and control' in text:
        list.append('math.OC')
    if 'computational machine learning' in text:
        list.append('cs.LG')

    return list

# %%
pred_df = test.copy() 
labels_for_prompt = ["Artificial Intelligence", "Computation and Language", "Statistics Machine Learning", "Optimization and Control", "Computational Machine Learning"]

for index, row in pred_df.iterrows():
    try:
        text = row['text']
        completion, request_time, completion_tokens, prompt_tokens, total_tokens = classify(text, labels_for_prompt)
        pred_df.at[index, 'prediction'] = completion
        pred_df.at[index, 'request_time'] = request_time
        pred_df.at[index, 'completion_tokens'] = completion_tokens
        pred_df.at[index, 'prompt_tokens'] = prompt_tokens
        pred_df.at[index, 'total_tokens'] = total_tokens

    except Exception as e:
        # Save the current state of the DataFrame to a file before breaking out or retrying.
        pred_df.to_csv("results/partial_gemini_ZS_multilabel3.csv", index=False)
        print(f"An error occurred at index {index}: {e}. Partial results saved.")
        # Optionally, you can break out of the loop or continue based on your needs.
        break

pred_df['prediction_post_processed'] = pred_df['prediction'].apply(post_process)
pred_df.to_csv("results/gemini_ZS_multilabel3.csv", index=False)

pred_df
# Out:
#                                                    text  cs.AI  cs.CL  cs.LG  \
# 0     FLAG: Fast Label-Adaptive Aggregation for Mult...      1      0      1
# 1       Large-Margin Classification in Hyperbolic Space      0      0      1
# 2     Student Specialization in Deep ReLU Networks W...      0      0      1
# 3     Joint Modelling of Emotion and Abusive Languag...      0      1      1
# 4     Allocation of Excitation Signals for Generic I...      0      0      0
# ...                                                 ...    ...    ...    ...
# 1265  Benign Overfitting in Two-layer Convolutional ...      0      0      1
# 1266  An FPGA-Based On-Device Reinforcement Learning...      0      0      1
# 1267  Something for (almost) nothing: Improving deep...      0      0      1
# 1268  An Alternative to Variance: Gini Deviation for...      1      0      1
# 1269  Concept Learning through Deep Reinforcement Le...      1      0      1
#
#       math.OC  stat.ML                                         prediction  \
# 0           0        0  artificial intelligence, statistics machine le...
# 1           0        1  statistics machine learning, computational mac...
# 2           0        1  statistics machine learning, computational mac...
# 3           0        0  artificial intelligence, computation and langu...
# 4           1        0                         optimization and control\n
# ...       ...      ...                                                ...
# 1265        1        1  statistics machine learning, computational mac...
# 1266        0        1  artificial intelligence, computational machine...
# 1267        0        0  statistics machine learning, computational mac...
# 1268        0        0  optimization and control, computational machin...
# 1269        0        0  artificial intelligence, computational machine...
#
#       request_time  completion_tokens  prompt_tokens  total_tokens  \
# 0         1.187085               11.0          109.0         120.0
# 1         1.182272                8.0          102.0         110.0
# 2         1.739889                8.0          107.0         115.0
# 3         1.247572               11.0          103.0         114.0
# 4         1.136825                4.0          108.0         112.0
# ...            ...                ...            ...           ...
# 1265      1.208312                8.0          106.0         114.0
# 1266      1.161395                7.0          108.0         115.0
# 1267      1.143463                8.0          109.0         117.0
# 1268      1.175672               11.0          109.0         120.0
# 1269      1.176056               11.0          107.0         118.0
#
#      prediction_post_processed
# 0      [cs.AI, stat.ML, cs.LG]
# 1             [stat.ML, cs.LG]
# 2             [stat.ML, cs.LG]
# 3      [cs.AI, cs.CL, stat.ML]
# 4                    [math.OC]
# ...                        ...
# 1265          [stat.ML, cs.LG]
# 1266            [cs.AI, cs.LG]
# 1267          [stat.ML, cs.LG]
# 1268   [cs.AI, math.OC, cs.LG]
# 1269   [cs.AI, stat.ML, cs.LG]
#
# [1270 rows x 12 columns]

# %%
for label in labels:
    pred_df[f"{label} pred"] = pred_df.apply(lambda row: 1 if label in row['prediction_post_processed'] else 0, axis=1)

pred_df = pred_df.drop(columns=['prediction'])

pred_df
# Out:
#                                                    text  cs.AI  cs.CL  cs.LG  \
# 0     FLAG: Fast Label-Adaptive Aggregation for Mult...      1      0      1
# 1       Large-Margin Classification in Hyperbolic Space      0      0      1
# 2     Student Specialization in Deep ReLU Networks W...      0      0      1
# 3     Joint Modelling of Emotion and Abusive Languag...      0      1      1
# 4     Allocation of Excitation Signals for Generic I...      0      0      0
# ...                                                 ...    ...    ...    ...
# 1265  Benign Overfitting in Two-layer Convolutional ...      0      0      1
# 1266  An FPGA-Based On-Device Reinforcement Learning...      0      0      1
# 1267  Something for (almost) nothing: Improving deep...      0      0      1
# 1268  An Alternative to Variance: Gini Deviation for...      1      0      1
# 1269  Concept Learning through Deep Reinforcement Le...      1      0      1
#
#       math.OC  stat.ML  request_time  completion_tokens  prompt_tokens  \
# 0           0        0      1.187085               11.0          109.0
# 1           0        1      1.182272                8.0          102.0
# 2           0        1      1.739889                8.0          107.0
# 3           0        0      1.247572               11.0          103.0
# 4           1        0      1.136825                4.0          108.0
# ...       ...      ...           ...                ...            ...
# 1265        1        1      1.208312                8.0          106.0
# 1266        0        1      1.161395                7.0          108.0
# 1267        0        0      1.143463                8.0          109.0
# 1268        0        0      1.175672               11.0          109.0
# 1269        0        0      1.176056               11.0          107.0
#
#       total_tokens prediction_post_processed  cs.AI pred  cs.CL pred  \
# 0            120.0   [cs.AI, stat.ML, cs.LG]           1           0
# 1            110.0          [stat.ML, cs.LG]           0           0
# 2            115.0          [stat.ML, cs.LG]           0           0
# 3            114.0   [cs.AI, cs.CL, stat.ML]           1           1
# 4            112.0                 [math.OC]           0           0
# ...            ...                       ...         ...         ...
# 1265         114.0          [stat.ML, cs.LG]           0           0
# 1266         115.0            [cs.AI, cs.LG]           1           0
# 1267         117.0          [stat.ML, cs.LG]           0           0
# 1268         120.0   [cs.AI, math.OC, cs.LG]           1           0
# 1269         118.0   [cs.AI, stat.ML, cs.LG]           1           0
#
#       stat.ML pred  math.OC pred  cs.LG pred
# 0                1             0           1
# 1                1             0           1
# 2                1             0           1
# 3                1             0           0
# 4                0             1           0
# ...            ...           ...         ...
# 1265             1             0           1
# 1266             0             0           1
# 1267             1             0           1
# 1268             0             1           1
# 1269             1             0           1
#
# [1270 rows x 16 columns]

# %%
y_true = pred_df[labels].values
y_pred = pred_df[[f"{label} pred" for label in labels]].values

#calculate the accuracy of the model
accuracy = accuracy_score(y_true, y_pred)
print('Accuracy: %f' % accuracy)
f1 = f1_score(y_true, y_pred, average='weighted')
print('F1 score: %f' % f1)
precision = precision_score(y_true, y_pred, average='weighted')
print('Precision: %f' % precision)
recall = recall_score(y_true, y_pred, average='weighted')
print('Recall: %f' % recall)
hamming_loss = hamming_loss(y_true, y_pred)
print('Hamming loss: %f' % hamming_loss)
# Out:
# Accuracy: 0.263780
# F1 score: 0.710397
# Precision: 0.640663
# Recall: 0.836524
# Hamming loss: 0.236535

# %%
# get average response time, vram usage and ram usage
request_time_avg = pred_df['request_time'].mean()
completion_tokens_avg = pred_df['completion_tokens'].mean()
prompt_tokens_avg = pred_df['prompt_tokens'].mean()
total_tokens_avg = pred_df['total_tokens'].mean()

print(f'Average response time: {request_time_avg}')
print(f'Average completion tokens: {completion_tokens_avg}')
print(f'Average prompt tokens: {prompt_tokens_avg}')
print(f'Average total tokens: {total_tokens_avg}')
# Out:
# Average response time: 1.0632561223713433
# Average completion tokens: 8.462992125984252
# Average prompt tokens: 106.4259842519685
# Average total tokens: 114.88897637795276

# %%
input_token_price = 0.1/1_000_000
output_token_price = 0.4/1_000_000

# Calculate the cost of the requests
total_cost = 0
for index, row in pred_df.iterrows():
    completion_tokens = row['completion_tokens']
    prompt_tokens = row['prompt_tokens']
    cost  = completion_tokens * output_token_price + prompt_tokens * input_token_price
    total_cost += cost

print(f'Total cost: USD {total_cost}')
# Out:
# Total cost: USD 0.017815299999999996

# %%
with open('results/gemini_ZS_multilabel3.txt', 'w') as f:
    f.write(f'Accuracy: {accuracy}\n')
    f.write(f'F1 score: {f1}\n')
    f.write(f'Precision: {precision}\n')
    f.write(f'Recall: {recall}\n')
    f.write(f'Hamming loss: {hamming_loss}\n')
    f.write(f'Average response time: {request_time_avg}\n')
    f.write(f'Average completion tokens: {completion_tokens_avg}\n')
    f.write(f'Average prompt tokens: {prompt_tokens_avg}\n')
    f.write(f'Average total tokens: {total_tokens_avg}\n')
    f.write(f'Total cost: USD {total_cost}\n')

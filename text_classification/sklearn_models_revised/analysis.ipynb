# %%
import pandas as pd

# %%
binary1 = pd.read_csv('results/results_sklearn_binary1.csv')
binary2 = pd.read_csv('results/results_sklearn_binary2.csv')

# %%
total_time_binary1 = binary1['training_time'].sum() + binary1['prediction_time'].sum()
total_time_binary2 = binary2['training_time'].sum() + binary2['prediction_time'].sum()

print('Total time binary1:', total_time_binary1/180)
print('Total time binary2:', total_time_binary2/180)
# Out:
# Total time binary1: 10.704901137237902
# Total time binary2: 10.575674209977862

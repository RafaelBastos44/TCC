# %% [markdown]
# # Importing libraries

# %%
# Basic libraries
import pandas as pd
import numpy as np
from datasets import load_dataset
import time
import pickle


# Classification models
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.multioutput import MultiOutputClassifier

# Vectorizers
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# Utilities and metrics
from itertools import product
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, hamming_loss
from memory_profiler import memory_usage


# Preprocessing
import nltk
import re

# Download nltk resources
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Rafael\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Setting seeds

# %%
s1 = 2
s2 = 3
s3 = 5

seeds = [s1, s2, s3]

# %% [markdown]
# # Importing datasets

# %%
ds = load_dataset("Arsive/toxicity_classification_jigsaw")

train = ds['train'].to_pandas()
val = ds['validation'].to_pandas()
test = ds['test'].to_pandas()

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25960 entries, 0 to 25959
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             25960 non-null  object
#  1   comment_text   25960 non-null  object
#  2   toxic          25960 non-null  int64
#  3   severe_toxic   25960 non-null  int64
#  4   obscene        25960 non-null  int64
#  5   threat         25960 non-null  int64
#  6   insult         25960 non-null  int64
#  7   identity_hate  25960 non-null  int64
# dtypes: int64(6), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# # Dataset preprocessing

# %%
test.describe()
# Out:
#                toxic   severe_toxic        obscene         threat  \
# count  153164.000000  153164.000000  153164.000000  153164.000000
# mean       -0.542530      -0.579895      -0.558193      -0.580913
# std         0.572465       0.498408       0.542966       0.496195
# min        -1.000000      -1.000000      -1.000000      -1.000000
# 25%        -1.000000      -1.000000      -1.000000      -1.000000
# 50%        -1.000000      -1.000000      -1.000000      -1.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#               insult  identity_hate
# count  153164.000000  153164.000000
# mean       -0.559916      -0.577642
# std         0.539594       0.503260
# min        -1.000000      -1.000000
# 25%        -1.000000      -1.000000
# 50%        -1.000000      -1.000000
# 75%         0.000000       0.000000
# max         1.000000       1.000000

# %%
test = test[test['toxic'] != -1]
test.describe()
# Out:
#               toxic  severe_toxic       obscene        threat        insult  \
# count  63978.000000  63978.000000  63978.000000  63978.000000  63978.000000
# mean       0.095189      0.005736      0.057692      0.003298      0.053565
# std        0.293478      0.075522      0.233161      0.057334      0.225160
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        identity_hate
# count   63978.000000
# mean        0.011129
# std         0.104905
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
train.rename(columns={'comment_text': 'text'}, inplace=True)
val.rename(columns={'comment_text': 'text'}, inplace=True)
test.rename(columns={'comment_text': 'text'}, inplace=True)

train = train.sample(frac=0.01, random_state=42)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, 15176 to 8037
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             260 non-null    object
#  1   text           260 non-null    object
#  2   toxic          260 non-null    int64
#  3   severe_toxic   260 non-null    int64
#  4   obscene        260 non-null    int64
#  5   threat         260 non-null    int64
#  6   insult         260 non-null    int64
#  7   identity_hate  260 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 18.3+ KB

# %%
stop_words = set(nltk.corpus.stopwords.words('english'))
lemmatizer = nltk.stem.WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()

    text = re.sub(r'[^\w\s]', '', text)
    
    words = text.split()
    words = [word for word in words if word not in stop_words]
    words = [lemmatizer.lemmatize(word) for word in words]

    return ' '.join(words)
train['text'] = train['text'].apply(preprocess_text)

# %% [markdown]
# # GridSearch implementation

# %%
vectorizers = [
    TfidfVectorizer(),
    CountVectorizer()
]

models = {
    'RandomForest': {
        'model': RandomForestClassifier(),
        'params': {
            'n_estimators': [50, 100, 150],
            'criterion': ['gini', 'entropy', 'log_loss']
        }
    },
    'SVC': {
        'model': MultiOutputClassifier(SVC()),
        'params': {
            'estimator__C': [0.1, 1, 10],
            'estimator__kernel': ['linear', 'rbf', 'sigmoid']
        }
    },
    'MultinomialNB': {
        'model': MultiOutputClassifier(MultinomialNB()),
        'params': {
            'estimator__alpha': [0.01, 0.1, 1.0]
        }
    },
    'LogisticRegression': {
        'model': MultiOutputClassifier(LogisticRegression(max_iter=1000)),
        'params': {
            'estimator__C': [0.1, 1, 10],
            'estimator__penalty': ['l2']
        }
    },
    'KNeighbors': {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [3, 5, 7],
            'algorithm': ['ball_tree', 'kd_tree', 'brute']
        }
    },
    'DecisionTree': {
        'model': DecisionTreeClassifier(),
        'params': {
            'criterion': ['gini', 'entropy', 'log_loss'],
            'max_features': ['sqrt', 'log2', None]
        }
    },
    'GradientBoosting': {
        'model': MultiOutputClassifier(GradientBoostingClassifier()),
        'params': {
            'estimator__n_estimators': [100, 150, 200],
            'estimator__criterion': ['friedman_mse', 'squared_error'],
        }
    },
    'AdaBoost': {
        'model': MultiOutputClassifier(AdaBoostClassifier()),
        'params': {
            'estimator__n_estimators': [50, 100, 150],
            'estimator__learning_rate': [0.01, 0.1, 1.0]
        }
    },
    'SGD': {
        'model': MultiOutputClassifier(SGDClassifier()),
        'params': {
            'estimator__alpha': [0.0001, 0.001, 0.01],
            'estimator__penalty': ['l2', 'l1', 'elasticnet']
        }
    }
}

# %%
columns = ['seed', 'vectorizer', 'model', 'params', 'accuracy', 'hamming_loss', 'training_time', 'prediction_time', 'peak_memory_train', 'peak_memory_prediction']

classes = list(train.columns[2:])
for c in classes:
    columns.extend([
        f'precision_class_{c}',
        f'recall_class_{c}',
        f'f1_class_{c}'
    ])

results = pd.DataFrame(columns=columns)

# %%
for seed in seeds:
    print(f"Processing seed: {seed}")
    for vectorizer in vectorizers:
        print(f"Processing vectorizer: {vectorizer.__class__.__name__}")
        for name, info in models.items():
            print(f"Processing model: {name}")

            model = info['model']
            param_grid = info['params']
            param_combinations = product(*param_grid.values())
            
            for combination in param_combinations:
                params = dict(zip(param_grid.keys(), combination))
                model.set_params(**params)
                if 'random_state' in model.get_params():
                    model.set_params(random_state=seed)

                print(f"Training {name} with params {params} and vectorizer {vectorizer.__class__.__name__}")

                pipeline = Pipeline([
                    ('vectorizer', vectorizer),
                    ('model', model)
                ])

                def train_model():
                    pipeline.fit(train['text'], train[classes])

                def predict_model():
                    return pipeline.predict(val['text'])

                # Training Phase
                start_time = time.perf_counter()
                peak_memory_train = memory_usage(train_model, max_usage=True)
                train_time = time.perf_counter() - start_time
                print(f"Training time: {train_time}")
                print(f"Peak memory usage during training: {peak_memory_train} MB")

                # Prediction Phase
                start_time = time.perf_counter()
                peak_memory_pred, y_pred = memory_usage(predict_model, max_usage=True, retval=True)
                prediction_time = time.perf_counter() - start_time
                print(f"Prediction time: {prediction_time}")
                print(f"Peak memory usage during prediction: {peak_memory_pred} MB")
                
                val_classes = val.drop(columns=['id', 'text'])

                accuracy = accuracy_score(val_classes, y_pred)
                print(y_pred.shape)
                
                precisions, recalls, f1s, supports = precision_recall_fscore_support(val_classes.to_numpy(), y_pred, average=None, zero_division=0)

                hamm_loss = hamming_loss(val_classes.to_numpy(), y_pred)

                result_dict = {
                    'seed': seed,
                    'vectorizer': vectorizer.__class__.__name__,
                    'model': name,
                    'params': params,
                    'accuracy': accuracy,
                    'hamming_loss': hamm_loss,
                    'training_time': train_time,
                    'prediction_time': prediction_time,
                    'peak_memory_train': peak_memory_train,
                    'peak_memory_prediction': peak_memory_pred,
                }

                for i, c in enumerate(classes):
                    result_dict[f'precision_class_{c}'] = precisions[i]
                    result_dict[f'recall_class_{c}'] = recalls[i]
                    result_dict[f'f1_class_{c}'] = f1s[i]

                result = pd.DataFrame([result_dict])
                results = pd.concat([results, result], ignore_index=True)
                print("-"*100)

results.to_csv('results/results_sklearn_multilabel1.csv', index=False)
# Out:
# Processing seed: 2
# Processing vectorizer: TfidfVectorizer
# Processing model: RandomForest
# Training RandomForest with params {'n_estimators': 50, 'criterion': 'gini'} and vectorizer TfidfVectorizer
# Training time: 1.1647097000386566
# Peak memory usage during training: 848.9453125 MB
# Prediction time: 1.3415602999739349
# Peak memory usage during prediction: 844.49609375 MB
# (6490, 6)
# ----------------------------------------------------------------------------------------------------
# Training RandomForest with params {'n_estimators': 50, 'criterion': 'entropy'} and vectorizer TfidfVectorizer
# C:\Users\Rafael\AppData\Local\Temp\ipykernel_9000\2730604156.py:73: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, result], ignore_index=True)
# Training time: 1.1548892999999225
# Peak memory usage during training: 836.26953125 MB
# Prediction time: 1.353047400014475
# Peak memory usage during prediction: 842.3046875 MB
# (6490, 6)
# ----------------------------------------------------------------------------------------------------
# Training RandomForest with params {'n_estimators': 50, 'criterion': 'log_loss'} and vectorizer TfidfVectorizer
# Training time: 1.1926349999848753
# Peak memory usage during training: 836.50390625 MB
# Prediction time: 1.3527277999091893
# Peak memory usage during prediction: 842.203125 MB
# (6490, 6)
# ----------------------------------------------------------------------------------------------------
# Training RandomForest with params {'n_estimators': 100, 'criterion': 'gini'} and vectorizer TfidfVectorizer
# Training time: 1.3421979000559077
# Peak memory usage during training: 837.61328125 MB
# Prediction time: 0.7253434000303969
# Peak memory usage during prediction: 842.96484375 MB
# (6490, 6)
# ----------------------------------------------------------------------------------------------------
# Training RandomForest with params {'n_estimators': 100, 'criterion': 'entropy'} and vectorizer TfidfVectorizer
# Training time: 0.7061254000291228
# Peak memory usage during training: 842.96484375 MB
# Prediction time: 0.7398797000059858
# Peak memory usage during prediction: 842.7265625 MB
# (6490, 6)
# ----------------------------------------------------------------------------------------------------
# Training RandomForest with params {'n_estimators': 100, 'criterion': 'log_loss'} and vectorizer TfidfVectorizer
# Training time: 0.7020056999754161
# Peak memory usage during training: 842.85546875 MB
# Prediction time: 0.7252962000202388
# Peak memory usage during prediction: 843.0859375 MB
# (6490, 6)
# ----------------------------------------------------------------------------------------------------
# Training RandomForest with params {'n_estimators': 150, 'criterion': 'gini'} and vectorizer TfidfVectorizer
# Training time: 0.7655696000438184
# Peak memory usage during training: 843.296875 MB

# %% [markdown]
# # Process results

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   seed                           396 non-null    object
#  1   vectorizer                     396 non-null    object
#  2   model                          396 non-null    object
#  3   params                         396 non-null    object
#  4   accuracy                       396 non-null    float64
#  5   training_time                  396 non-null    float64
#  6   prediction_time                396 non-null    float64
#  7   peak_memory_train              396 non-null    float64
#  8   peak_memory_prediction         396 non-null    float64
#  9   precision_class_toxic          396 non-null    float64
#  10  recall_class_toxic             396 non-null    float64
#  11  f1_class_toxic                 396 non-null    float64
#  12  precision_class_severe_toxic   396 non-null    float64
#  13  recall_class_severe_toxic      396 non-null    float64
#  14  f1_class_severe_toxic          396 non-null    float64
#  15  precision_class_obscene        396 non-null    float64
#  16  recall_class_obscene           396 non-null    float64
#  17  f1_class_obscene               396 non-null    float64
#  18  precision_class_threat         396 non-null    float64
#  19  recall_class_threat            396 non-null    float64
#  20  f1_class_threat                396 non-null    float64
#  21  precision_class_insult         396 non-null    float64
#  22  recall_class_insult            396 non-null    float64
#  23  f1_class_insult                396 non-null    float64
#  24  precision_class_identity_hate  396 non-null    float64
#  25  recall_class_identity_hate     396 non-null    float64
#  26  f1_class_identity_hate         396 non-null    float64
# dtypes: float64(23), object(4)
# memory usage: 83.7+ KB

# %%
results.head()
# Out:
#   seed       vectorizer         model  \
# 0    2  TfidfVectorizer  RandomForest
# 1    2  TfidfVectorizer  RandomForest
# 2    2  TfidfVectorizer  RandomForest
# 3    2  TfidfVectorizer  RandomForest
# 4    2  TfidfVectorizer  RandomForest
#
#                                           params  accuracy  training_time  \
# 0      {'n_estimators': 50, 'criterion': 'gini'}  0.534206       1.149115
# 1   {'n_estimators': 50, 'criterion': 'entropy'}  0.539753       0.893782
# 2  {'n_estimators': 50, 'criterion': 'log_loss'}  0.539753       1.154756
# 3     {'n_estimators': 100, 'criterion': 'gini'}  0.545917       1.329363
# 4  {'n_estimators': 100, 'criterion': 'entropy'}  0.544992       0.704777
#
#    prediction_time  peak_memory_train  peak_memory_prediction  \
# 0         1.334285         832.828125              835.640625
# 1         1.332878         835.644531              834.722656
# 2         1.348080         833.531250              832.558594
# 3         0.729114         826.187500              832.937500
# 4         0.733598         832.941406              825.183594
#
#    precision_class_toxic  ...  f1_class_obscene  precision_class_threat  \
# 0               0.813614  ...          0.530559                     0.0
# 1               0.802174  ...          0.491921                     0.0
# 2               0.802174  ...          0.491921                     0.0
# 3               0.892568  ...          0.524978                     0.0
# 4               0.798498  ...          0.508913                     0.0
#
#    recall_class_threat  f1_class_threat  precision_class_insult  \
# 0                  0.0              0.0                0.758904
# 1                  0.0              0.0                0.788413
# 2                  0.0              0.0                0.788413
# 3                  0.0              0.0                0.769231
# 4                  0.0              0.0                0.804598
#
#    recall_class_insult  f1_class_insult  precision_class_identity_hate  \
# 0             0.177678         0.287942                            1.0
# 1             0.200770         0.320041                            1.0
# 2             0.200770         0.320041                            1.0
# 3             0.166774         0.274117                            0.0
# 4             0.179602         0.293655                            1.0
#
#    recall_class_identity_hate  f1_class_identity_hate
# 0                    0.003817                0.007605
# 1                    0.003817                0.007605
# 2                    0.003817                0.007605
# 3                    0.000000                0.000000
# 4                    0.003817                0.007605
#
# [5 rows x 27 columns]

# %%
results['params'] = results['params'].astype(str)
results_avg_seed = results.groupby(['model', 'vectorizer', 'params']).mean().reset_index()
results_avg_seed['f1_avg'] = results_avg_seed[[col for col in results_avg_seed.columns if 'f1_class' in col]].mean(axis=1)
results_avg_seed
# Out:
#         model       vectorizer  \
# 0    AdaBoost  CountVectorizer
# 1    AdaBoost  CountVectorizer
# 2    AdaBoost  CountVectorizer
# 3    AdaBoost  CountVectorizer
# 4    AdaBoost  CountVectorizer
# ..        ...              ...
# 127       SVC  TfidfVectorizer
# 128       SVC  TfidfVectorizer
# 129       SVC  TfidfVectorizer
# 130       SVC  TfidfVectorizer
# 131       SVC  TfidfVectorizer
#
#                                                 params      seed  accuracy  \
# 0    {'estimator__n_estimators': 100, 'estimator__l...  3.333333  0.534977
# 1    {'estimator__n_estimators': 100, 'estimator__l...  3.333333  0.361839
# 2    {'estimator__n_estimators': 100, 'estimator__l...  3.333333  0.343760
# 3    {'estimator__n_estimators': 150, 'estimator__l...  3.333333  0.540010
# 4    {'estimator__n_estimators': 150, 'estimator__l...  3.333333  0.455316
# ..                                                 ...       ...       ...
# 127    {'estimator__C': 1, 'estimator__kernel': 'rbf'}  3.333333  0.538367
# 128  {'estimator__C': 1, 'estimator__kernel': 'sigm...  3.333333  0.556394
# 129  {'estimator__C': 10, 'estimator__kernel': 'lin...  3.333333  0.531587
# 130   {'estimator__C': 10, 'estimator__kernel': 'rbf'}  3.333333  0.555624
# 131  {'estimator__C': 10, 'estimator__kernel': 'sig...  3.333333  0.502003
#
#      training_time  prediction_time  peak_memory_train  \
# 0         1.518558         0.967381         829.490885
# 1         1.546520         1.039813         829.442708
# 2         1.623639         1.006274         829.444010
# 3         2.108233         1.156371         829.464844
# 4         2.075261         1.160997         829.506510
# ..             ...              ...                ...
# 127       1.026851         1.557175         823.078125
# 128       0.998959         1.107137         824.958333
# 129       1.006885         1.150323         823.105469
# 130       1.024329         1.563466         823.123698
# 131       1.004538         1.081542         825.013021
#
#      peak_memory_prediction  precision_class_toxic  ...  \
# 0                829.442708               0.964796  ...
# 1                829.446615               0.604374  ...
# 2                829.464844               0.625012  ...
# 3                829.510417               0.962065  ...
# 4                829.764323               0.691897  ...
# ..                      ...                    ...  ...
# 127              829.653646               0.908851  ...
# 128              829.528646               0.814186  ...
# 129              829.643229               0.753951  ...
# 130              829.597656               0.823787  ...
# 131              829.859375               0.730093  ...
#
#      precision_class_threat  recall_class_threat  f1_class_threat  \
# 0                  0.033086             0.015152         0.020733
# 1                  0.010417             0.003788         0.005556
# 2                  0.017544             0.003788         0.006231
# 3                  0.030025             0.011364         0.016485
# 4                  0.020833             0.007576         0.011111
# ..                      ...                  ...              ...
# 127                0.000000             0.000000         0.000000
# 128                0.000000             0.000000         0.000000
# 129                0.000000             0.000000         0.000000
# 130                0.000000             0.000000         0.000000
# 131                0.333333             0.011364         0.021978
#
#      precision_class_insult  recall_class_insult  f1_class_insult  \
# 0                  0.623077             0.051956         0.095915
# 1                  0.673522             0.336113         0.448435
# 2                  0.565009             0.481291         0.519790
# 3                  0.714286             0.093008         0.164586
# 4                  0.653311             0.418217         0.509965
# ..                      ...                  ...              ...
# 127                0.868132             0.050674         0.095758
# 128                0.785064             0.276459         0.408918
# 129                0.670412             0.459269         0.545108
# 130                0.843666             0.200770         0.324352
# 131                0.582315             0.519564         0.549153
#
#      precision_class_identity_hate  recall_class_identity_hate  \
# 0                         0.227273                    0.019084
# 1                         0.048204                    0.194656
# 2                         0.162043                    0.162850
# 3                         0.250000                    0.022901
# 4                         0.099417                    0.167939
# ..                             ...                         ...
# 127                       0.000000                    0.000000
# 128                       0.333333                    0.007634
# 129                       0.361702                    0.129771
# 130                       0.555556                    0.019084
# 131                       0.226601                    0.175573
#
#      f1_class_identity_hate    f1_avg
# 0                  0.035211  0.221203
# 1                  0.077273  0.332759
# 2                  0.144231  0.366275
# 3                  0.041958  0.235333
# 4                  0.124891  0.343738
# ..                      ...       ...
# 127                0.000000  0.165338
# 128                0.014925  0.282629
# 129                0.191011  0.388972
# 130                0.036900  0.268598
# 131                0.197849  0.404836
#
# [132 rows x 28 columns]

# %%
best_result = results_avg_seed.loc[results_avg_seed['f1_avg'].idxmax()]

best_model = models[best_result['model']]['model']
best_params = eval(best_result['params'])
best_model.set_params(**best_params)

best_result_vectorizer = eval(best_result['vectorizer'])()

pipeline = Pipeline([
    ('vectorizer', best_result_vectorizer),
    ('model', best_model)
])

pipeline.fit(train['text'], train[classes])
y_pred = pipeline.predict(test['text'])

accuracy = accuracy_score(test[classes], y_pred)
precisions, recalls, f1s, supports = precision_recall_fscore_support(test[classes], y_pred, average=None, zero_division=0)

print(f"Best model: {best_result['model']}")
print(f"Best model params: {best_result['params']}")
print(f"Best vectorizer: {best_result['vectorizer']}")
print(f"Best accuracy: {accuracy}\n")

for i, c in enumerate(classes):
    print(f"Class {c}")
    print(f"Precision: {precisions[i]}")
    print(f"Recall: {recalls[i]}")
    print(f"F1: {f1s[i]}")
    print(f"Support: {supports[i]}\n")
# Out:
# Best model: MultinomialNB
# Best model params: {'estimator__alpha': 0.1}
# Best vectorizer: CountVectorizer
# Best accuracy: 0.7611522710931883
#
# Class toxic
# Precision: 0.32996920971604515
# Recall: 0.6334975369458128
# F1: 0.4339219435384096
# Support: 6090
#
# Class severe_toxic
# Precision: 0.1549876339653751
# Recall: 0.5122615803814714
# F1: 0.2379746835443038
# Support: 367
#
# Class obscene
# Precision: 0.36729435084241824
# Recall: 0.5020319696559198
# F1: 0.4242216117216117
# Support: 3691
#
# Class threat
# Precision: 0.023391812865497075
# Recall: 0.037914691943127965
# F1: 0.028933092224231464
# Support: 211
#
# Class insult
# Precision: 0.28019158398905236
# Recall: 0.47796906915669685
# F1: 0.3532837269492074
# Support: 3427
#
# Class identity_hate
# Precision: 0.0982749607945635
# Recall: 0.2640449438202247
# F1: 0.14323809523809525
# Support: 712

# %%
with open('models/best_model_sklearn_multilabel1.pkl', 'wb') as f:
    pickle.dump(pipeline, f)
